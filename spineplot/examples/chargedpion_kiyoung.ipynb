# %%
import toml
import os
import sys
workspace_root = os.getcwd()  
sys.path.insert(0, workspace_root + "/..")
from analysis import Analysis

# %%
cfg = """
[[this_includes]]
file = '../configurations/common/variables.toml'

[[this_includes]]
file = '../configurations/common/styles.toml'

[samples]
[samples.mc]
key = "nominal"
exposure_type = "pot"
trees = ['selected']

[output]
path = 'plot'

[analysis]
ordinate_sample = 'mc'
category_branch = 'true_category'
category_assignment = [[0], [1], [2], [3], [4], [5], [6]]
category_labels = ['1$\\mu$1pi', '1$\\mu$Npi', '1$\\mu$0pi', 'Other CC','NC','Out of FV','Cosmic']
category_colors = ['C0', 'C1', 'C3','C4', 'C5', 'C6', 'C7']
category_types = ['histogram', 'histogram', 'histogram','histogram','histogram','histogram','histogram']

[[figure]]
name = 'true_category'
type = 'SimpleFigure'
style = 'selected_icarus'
[[figure.artists]]
type = 'SpineSpectra1D'
variable = 'true_category'
draw_kwargs = {'show_component_number' = true, 'show_component_percentage' = true, 'invert_stack_order' = false}
"""
# Write the string to a file
with open('cfg.toml', 'w') as f:
    f.write(cfg)

file = '/Users/rvizarreta/Library/CloudStorage/GoogleDrive-rvizarreta14@gmail.com/My Drive/🏛 PhD Repository/🚀 Research/🤖 Experiments&Projects/ICARUS/ICARUS_CC0pi_Selection/data/icarus_charged_pion.root'

analysis = Analysis('cfg.toml', file)
analysis.run(close_figs=False)
# Out:
# Setting weight for mc to 1.00e+00

# %%
cfg = """
[[this_includes]]
file = '../configurations/common/variables.toml'

[[this_includes]]
file = '../configurations/common/styles.toml'

[samples]
[samples.mc]
key = "nominal"
exposure_type = "pot"
trees = ['selected']

[variables.true_leading_muon_ke]
key = "true_leading_muon_ke"
range = [0, 3000]
nbins = 15
binning_scheme = "equal_population"
xlabel = "True Leading Muon Kinetic Energy [MeV]"

[output]
path = '/exp/icarus/app/users/kyjung/medulla_work'

[analysis]
ordinate_sample = 'mc'
category_branch = 'true_category'
category_assignment = [[0], [1], [2],[3], [4], [5], [6]]
category_labels = ['1$\\mu$1pi', '1$\\mu$Npi', '1$\\mu$0pi', 'Other CC','NC','Out of FV','Cosmic']
category_colors = ['C0', 'C1', 'C3','C4', 'C5', 'C6', 'C7']
category_types = ['histogram', 'histogram', 'histogram','histogram','histogram','histogram','histogram']

[[figure]]
name = 'true_leading_muon_ke'
type = 'SimpleFigure'
style = 'selected_icarus'
[[figure.artists]]
type = 'SpineSpectra1D'
variable = 'true_leading_muon_ke'
draw_kwargs = {'show_component_number' = true, 'show_component_percentage' = true, 'invert_stack_order' = false}
"""
# Write the string to a file
with open('cfg.toml', 'w') as f:
    f.write(cfg)

file = '/exp/icarus/app/users/kyjung/medulla_work/ICARUS-NuMI-CC0pi-Selection/build/icarus_charged_pion.root'

analysis = Analysis('cfg.toml', file)
analysis.run(close_figs=False)
# Out:
# Setting weight for mc to 1.00e+00

# %%
cfg = """
[[this_includes]]
file = '../configurations/common/variables.toml'

[[this_includes]]
file = '../configurations/common/styles.toml'

[samples]
[samples.mc]
key = "nominal"
exposure_type = "pot"
trees = ['selected']

[variables.true_leading_muon_ke]
key = "true_leading_muon_ke"
range = [0, 3000]
nbins = 15
binning_scheme = "equal_population"
xlabel = "True Leading Muon Kinetic Energy [MeV]"

[output]
path = '/exp/icarus/app/users/kyjung/medulla_work'

[analysis]
ordinate_sample = 'mc'
category_branch = 'true_interaction_mode'
category_assignment = [[0], [1], [2], [3],[10],[-1]]
category_labels = ['CCQE', 'RES', 'DIS', 'COH', 'MEC','NC']
category_colors = ['C0', 'C1', 'C3','C4', 'C5', 'C6', 'C7', 'C8']
category_types = ['histogram', 'histogram', 'histogram','histogram','histogram','histogram','histogram','histogram']

[[figure]]
name = 'true_leading_muon_ke'
type = 'SimpleFigure'
style = 'selected_icarus'
[[figure.artists]]
type = 'SpineSpectra1D'
variable = 'true_leading_muon_ke'
draw_kwargs = {'show_component_number' = true, 'show_component_percentage' = true, 'invert_stack_order' = false}
"""
# Write the string to a file
with open('cfg.toml', 'w') as f:
    f.write(cfg)

file = '/exp/icarus/app/users/kyjung/medulla_work/ICARUS-NuMI-CC0pi-Selection/build/icarus_charged_pion.root'

analysis = Analysis('cfg.toml', file)
analysis.run(close_figs=False)
# Out:
# Found NaN category in Sample `mc` with 7 occurrence(s). Masking NaNs...
# Setting weight for mc to 1.00e+00

# %%
cfg = """
[[this_includes]]
file = '../configurations/common/variables.toml'

[[this_includes]]
file = '../configurations/common/styles.toml'

[samples]
[samples.mc]
key = "nominal"
exposure_type = "pot"
trees = ['signal']

[variables.true_leading_muon_ke]
key = "true_leading_muon_ke"
range = [0, 3000]
nbins = 15
binning_scheme = "equal_population"
xlabel = "True Leading Muon Kinetic Energy [MeV]"

[output]
path = '/exp/icarus/app/users/kyjung/medulla_work'

[analysis]
ordinate_sample = 'mc'
category_branch = 'true_interaction_mode'
category_assignment = [[0], [1], [2], [3],[10],[-1]]
category_labels = ['CCQE', 'RES', 'DIS', 'COH', 'MEC','NC']
category_colors = ['C0', 'C1', 'C3','C4', 'C5', 'C6', 'C7', 'C8']
category_types = ['histogram', 'histogram', 'histogram','histogram','histogram','histogram','histogram','histogram']

[[figure]]
name = 'true_leading_muon_ke'
type = 'SimpleFigure'
style = 'selected_icarus'
[[figure.artists]]
type = 'SpineSpectra1D'
variable = 'true_leading_muon_ke'
draw_kwargs = {'show_component_number' = true, 'show_component_percentage' = true, 'invert_stack_order' = false}
"""
# Write the string to a file
with open('cfg.toml', 'w') as f:
    f.write(cfg)

file = '/exp/icarus/app/users/kyjung/medulla_work/ICARUS-NuMI-CC0pi-Selection/build/icarus_charged_pion.root'

analysis = Analysis('cfg.toml', file)
analysis.run(close_figs=False)
# Out:
# Setting weight for mc to 1.00e+00
