# %%
import toml
import os
import sys
workspace_root = os.getcwd()
sys.path.insert(0, workspace_root + "/..")
from analysis import Analysis

# %% [markdown]
# ## CONTAINED SAMPLE ONLY

# %%
# ANALYSIS SPECIFIC DIRECTORIES
ana_directory = "__ARCHIVE__/1muNp0pi_Nge1_contained"
data_file = '/Users/rvizarreta/Library/CloudStorage/GoogleDrive-rvizarreta14@gmail.com/My Drive/🏛 PhD Repository/🚀 Research/🤖 Experiments&Projects/ICARUS/ICARUS_CC0pi_Selection/data/1muNp0pi_Nge1_contained.root'

# %%
# Leading muon KE csda range plots
analysis = Analysis(ana_directory + '/leading_muon_ke_csda/leading_muon_ke_csda.toml', data_file)
analysis.run(close_figs=False)
# Out:
# ...
# Processing systematics for sample: mc
# ...
#
# ...
# Processing systematics for sample: onbeam
# ...
# Setting weight for mc to 1.51e-01
# Setting weight for onbeam to 1.00e+00

# %%
# Leading muon KE mcs plots
analysis = Analysis(ana_directory + '/leading_muon_ke_mcs/leading_muon_ke_mcs.toml', data_file)
analysis.run(close_figs=False)
# Out:
# ...
# Processing systematics for sample: mc
# ...
#
# ...
# Processing systematics for sample: onbeam
# ...
# Setting weight for mc to 1.51e-01
# Setting weight for onbeam to 1.00e+00

# %%
# Leading muon KE plots
analysis = Analysis(ana_directory + '/leading_muon_ke/leading_muon_ke.toml', data_file)
analysis.run(close_figs=False)
# Out:
# ...
# Processing systematics for sample: mc
# ...
#
# ...
# Processing systematics for sample: onbeam
# ...
# Setting weight for mc to 1.51e-01
# Setting weight for onbeam to 1.00e+00

# %%
# Leading muon KE smearing comparison plot in DATA
analysis = Analysis(ana_directory + '/leading_muon_ke/leading_muon_ke_smearing_data.toml', data_file)
analysis.run(close_figs=False)
# Out:
# ...
# Processing systematics for sample: onbeam
# ...
# Setting weight for onbeam to 1.00e+00

# %%
# Leading muon KE smearing comparison plot in MC
analysis = Analysis(ana_directory + '/leading_muon_ke/leading_muon_ke_smearing_mc.toml', data_file)
analysis.run(close_figs=False)
# Out:
# ...
# Processing systematics for sample: mc
# ...
# Setting weight for mc to 1.00e+00

# %%
# Leading muon length plots
analysis = Analysis(ana_directory + '/leading_muon_length/leading_muon_length.toml', data_file)
analysis.run(close_figs=False)
# Out:
# ...
# Processing systematics for sample: mc
# ...
#
# ...
# Processing systematics for sample: onbeam
# ...
# Setting weight for mc to 1.51e-01
# Setting weight for onbeam to 1.00e+00

# %% [markdown]
# ## UNCONTAINED SAMPLE ONLY

# %%
# ANALYSIS SPECIFIC DIRECTORIES
ana_directory = "__ARCHIVE__/1muNp0pi_Nge1_contained"
data_file = '/Users/rvizarreta/Library/CloudStorage/GoogleDrive-rvizarreta14@gmail.com/My Drive/🏛 PhD Repository/🚀 Research/🤖 Experiments&Projects/ICARUS/ICARUS_CC0pi_Selection/data/1muNp0pi_Nge1_uncontained_only.root'

# %%
# Leading muon KE csda range plots
analysis = Analysis(ana_directory + '/leading_muon_ke_csda/leading_muon_ke_csda.toml', data_file)
analysis.run(close_figs=False)
# Out:
# ...
# Processing systematics for sample: mc
# ...
#
# ...
# Processing systematics for sample: onbeam
# ...
# Setting weight for mc to 1.51e-01
# Setting weight for onbeam to 1.00e+00

# %%
# Leading muon KE mcs plots
analysis = Analysis(ana_directory + '/leading_muon_ke_mcs/leading_muon_ke_mcs.toml', data_file)
analysis.run(close_figs=False)
# Out:
# ...
# Processing systematics for sample: mc
# ...
#
# ...
# Processing systematics for sample: onbeam
# ...
# Setting weight for mc to 1.51e-01
# Setting weight for onbeam to 1.00e+00

# %%
# Leading muon KE plots
analysis = Analysis(ana_directory + '/leading_muon_ke/leading_muon_ke.toml', data_file)
analysis.run(close_figs=False)
# Out:
# ...
# Processing systematics for sample: mc
# ...
#
# ...
# Processing systematics for sample: onbeam
# ...
# Setting weight for mc to 1.51e-01
# Setting weight for onbeam to 1.00e+00

# %%
# Leading muon KE smearing comparison plot in DATA
analysis = Analysis(ana_directory + '/leading_muon_ke/leading_muon_ke_smearing_data.toml', data_file)
analysis.run(close_figs=False)
# Out:
# ...
# Processing systematics for sample: onbeam
# ...
# Setting weight for onbeam to 1.00e+00

# %%
# Leading muon KE smearing comparison plot in MC
analysis = Analysis(ana_directory + '/leading_muon_ke/leading_muon_ke_smearing_mc.toml', data_file)
analysis.run(close_figs=False)
# Out:
# ...
# Processing systematics for sample: mc
# ...
# Setting weight for mc to 1.00e+00

# %%
# Leading muon KE mcs plots
analysis = Analysis(ana_directory + '/leading_muon_length/leading_muon_length.toml', data_file)
analysis.run(close_figs=False)
# Out:
# ...
# Processing systematics for sample: mc
# ...
#
# ...
# Processing systematics for sample: onbeam
# ...
# Setting weight for mc to 1.51e-01
# Setting weight for onbeam to 1.00e+00

# %% [markdown]
# ## CONTAINED + UNCONTAINED SAMPLES

# %%
# ANALYSIS SPECIFIC DIRECTORIES
ana_directory = "__ARCHIVE__/1muNp0pi_Nge1_contained"
data_file = '/Users/rvizarreta/Library/CloudStorage/GoogleDrive-rvizarreta14@gmail.com/My Drive/🏛 PhD Repository/🚀 Research/🤖 Experiments&Projects/ICARUS/ICARUS_CC0pi_Selection/data/1muNp0pi_Nge1_uncontained.root'

# %%
# Leading muon KE csda range plots
analysis = Analysis(ana_directory + '/leading_muon_ke_csda/leading_muon_ke_csda.toml', data_file)
analysis.run(close_figs=False)
# Out:
# ...
# Processing systematics for sample: mc
# ...
#
# ...
# Processing systematics for sample: onbeam
# ...
# Setting weight for mc to 1.51e-01
# Setting weight for onbeam to 1.00e+00

# %%
# Leading muon KE mcs plots
analysis = Analysis(ana_directory + '/leading_muon_ke_mcs/leading_muon_ke_mcs.toml', data_file)
analysis.run(close_figs=False)
# Out:
# ...
# Processing systematics for sample: mc
# ...
#
# ...
# Processing systematics for sample: onbeam
# ...
# Setting weight for mc to 1.51e-01
# Setting weight for onbeam to 1.00e+00

# %%
# Leading muon KE plots
analysis = Analysis(ana_directory + '/leading_muon_ke/leading_muon_ke.toml', data_file)
analysis.run(close_figs=False)
# Out:
# ...
# Processing systematics for sample: mc
# ...
#
# ...
# Processing systematics for sample: onbeam
# ...
# Setting weight for mc to 1.51e-01
# Setting weight for onbeam to 1.00e+00

# %%
# Leading muon KE smearing comparison plot in DATA
analysis = Analysis(ana_directory + '/leading_muon_ke/leading_muon_ke_smearing_data.toml', data_file)
analysis.run(close_figs=False)
# Out:
# ...
# Processing systematics for sample: onbeam
# ...
# Setting weight for onbeam to 1.00e+00

# %%
# Leading muon KE smearing comparison plot in MC
analysis = Analysis(ana_directory + '/leading_muon_ke/leading_muon_ke_smearing_mc.toml', data_file)
analysis.run(close_figs=False)
# Out:
# ...
# Processing systematics for sample: mc
# ...
# Setting weight for mc to 1.00e+00

# %%
# Leading muon length plots
analysis = Analysis(ana_directory + '/leading_muon_length/leading_muon_length.toml', data_file)
analysis.run(close_figs=False)
# Out:
# ...
# Processing systematics for sample: mc
# ...
#
# ...
# Processing systematics for sample: onbeam
# ...
# Setting weight for mc to 1.51e-01
# Setting weight for onbeam to 1.00e+00
