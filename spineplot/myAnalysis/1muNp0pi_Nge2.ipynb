# %%
import toml
import os
import sys
workspace_root = os.getcwd()  
sys.path.insert(0, workspace_root + "/..")
from analysis import Analysis

# %%
cfg = """
[[this_includes]]
file = '../configurations/common/variables.toml'

[[this_includes]]
file = '../configurations/common/styles.toml'

[samples]
[samples.mc]
key = "nominal"
exposure_type = "pot"
trees = ['selected']

[output]
path = '/Users/rvizarreta/Library/CloudStorage/GoogleDrive-rvizarreta14@gmail.com/My Drive/🏛 PhD Repository/🚀 Research/🤖 Experiments&Projects/ICARUS/ICARUS_CC0pi_Selection/ICARUS-NuMI-CC0pi-Selection/spineplot/myAnalysis/1muNp0pi_Nge2'

[analysis]
ordinate_sample = 'mc'
category_branch = 'true_category'
category_assignment = [[0], [1], [2], [3], [4], [5], [6]]
category_labels = ['1$\\mu Np 0\\pi$', '1$\\mu 1p0 \\pi$', '1$\\mu 0p 0\\pi$', 'Other CC','NC','Out of FV','Cosmic']
category_colors = ['C0', 'C1', 'C3','C4', 'C5', 'C6', 'C7']
category_types = ['histogram', 'histogram', 'histogram','histogram','histogram','histogram','histogram']

[[figure]]
name = 'true_category'
type = 'SimpleFigure'
style = 'selected_icarus_1muNp0pi_N>=2'
[[figure.artists]]
type = 'SpineSpectra1D'
variable = 'true_category'
draw_kwargs = {'show_component_number' = true, 'show_component_percentage' = true, 'invert_stack_order' = false}

[[figure]]
name = 'true_visible_energy'
type = 'SimpleFigure'
style = 'selected_icarus_1muNp0pi_N>=2'
[[figure.artists]]
type = 'SpineSpectra1D'
variable = 'true_visible_energy'
draw_kwargs = {'show_component_number' = true, 'show_component_percentage' = true, 'invert_stack_order' = false}

[[figure]]
name = 'reco_visible_energy'
type = 'SimpleFigure'
style = 'selected_icarus_1muNp0pi_N>=2'
[[figure.artists]]
type = 'SpineSpectra1D'
variable = 'reco_visible_energy'
draw_kwargs = {'show_component_number' = true, 'show_component_percentage' = true, 'invert_stack_order' = false}

[[figure]]
name = 'true_dpT'
type = 'SimpleFigure'
style = 'selected_icarus_1muNp0pi_N>=2'
[[figure.artists]]
type = 'SpineSpectra1D'
variable = 'true_dpT'
draw_kwargs = {'show_component_number' = true, 'show_component_percentage' = true, 'invert_stack_order' = false}

[[figure]]
name = 'reco_dpT'
type = 'SimpleFigure'
style = 'selected_icarus_1muNp0pi_N>=2'
[[figure.artists]]
type = 'SpineSpectra1D'
variable = 'reco_dpT'
draw_kwargs = {'show_component_number' = true, 'show_component_percentage' = true, 'invert_stack_order' = false}
"""
# Write the string to a file
with open('cfg.toml', 'w') as f:
    f.write(cfg)

file = '/Users/rvizarreta/Library/CloudStorage/GoogleDrive-rvizarreta14@gmail.com/My Drive/🏛 PhD Repository/🚀 Research/🤖 Experiments&Projects/ICARUS/ICARUS_CC0pi_Selection/data/1muNp0pi_Nge2.root'

analysis = Analysis('cfg.toml', file)
analysis.run(close_figs=False)
# Out:
# ---------------------------------------------------------------------------
# TomlDecodeError                           Traceback (most recent call last)
# Cell In[13], line 76
#      72     f.write(cfg)
#      74 file = '/Users/rvizarreta/Library/CloudStorage/GoogleDrive-rvizarreta14@gmail.com/My Drive/🏛 PhD Repository/🚀 Research/🤖 Experiments&Projects/ICARUS/ICARUS_CC0pi_Selection/data/1muNp0pi_Nge2.root'
# ---> 76 analysis = Analysis('cfg.toml', file)
#      77 analysis.run(close_figs=False)
#
# File ~/Library/CloudStorage/GoogleDrive-rvizarreta14@gmail.com/My Drive/🏛 PhD Repository/🚀 Research/🤖 Experiments&Projects/ICARUS/ICARUS_CC0pi_Selection/ICARUS-NuMI-CC0pi-Selection/spineplot/myAnalysis/../analysis.py:57, in Analysis.__init__(self, toml_path, rf_path)
#      55 self._config = toml.load(self._toml_path)
#      56 for table in self._config.get('this_includes', []):
# ---> 57     Analysis.handle_include(self._config, table)
#      58 rf = uproot.open(rf_path)
#      60 # Load the output path
#
# File ~/Library/CloudStorage/GoogleDrive-rvizarreta14@gmail.com/My Drive/🏛 PhD Repository/🚀 Research/🤖 Experiments&Projects/ICARUS/ICARUS_CC0pi_Selection/ICARUS-NuMI-CC0pi-Selection/spineplot/myAnalysis/../analysis.py:316, in Analysis.handle_include(config, table)
#     295 """
#     296 Handles the inclusion of other configuration files in the main
#     297 configuration file. The include directive may also contain some
#    (...)
#     313 None.
#     314 """
#     315 with open(table['file'], 'r') as f:
# --> 316     c = toml.load(f)
#     317     if 'choose' in table.keys():
#     318         for key, value in table['choose'].items():
#
# File /opt/anaconda3/lib/python3.13/site-packages/toml/decoder.py:156, in load(f, _dict, decoder)
#     154 else:
#     155     try:
# --> 156         return loads(f.read(), _dict, decoder)
#     157     except AttributeError:
#     158         raise TypeError("You can only load a file descriptor, filename or "
#     159                         "list")
#
# File /opt/anaconda3/lib/python3.13/site-packages/toml/decoder.py:478, in loads(s, _dict, decoder)
#     475             currentlevel[group].append(decoder.get_empty_table()
#     476                                        )
#     477         else:
# --> 478             raise TomlDecodeError("What? " + group +
#     479                                   " already exists?" +
#     480                                   str(currentlevel),
#     481                                   original, pos)
#     482 except TypeError:
#     483     currentlevel = currentlevel[-1]
#
# TomlDecodeError: What? reco_dpT already exists?{'true_category': {'key': 'true_category', 'range': [0, 9], 'nbins': 9, 'xlabel': 'Category'}, 'true_visible_energy': {'key': 'true_visible_energy', 'range': [0, 3], 'nbins': 25, 'xlabel': 'True Visible Energy [GeV]'}, 'reco_visible_energy': {'key': 'reco_visible_energy', 'range': [0, 3], 'nbins': 25, 'xlabel': 'Reconstructed Visible Energy [GeV]'}, 'true_dpT': {'key': 'true_dpT', 'range': [0, 1200], 'nbins': 25, 'xlabel': 'True $\\delta p_T$ [MeV/c]'}, 'reco_dpT': {'key': 'reco_dpT', 'range': [0, 1200], 'nbins': 25, 'xlabel': 'Reconstructed $\\delta p_T$ [MeV/c]'}} (line 34 column 1 char 582)

# %%
cfg = r"""
[output]
path = "/Users/rvizarreta/Library/CloudStorage/GoogleDrive-rvizarreta14@gmail.com/My Drive/🏛 PhD Repository/🚀 Research/🤖 Experiments&Projects/ICARUS/ICARUS_CC0pi_Selection/ICARUS-NuMI-CC0pi-Selection/spineplot/myAnalysis/1muNp0pi_Nge2"

[samples.signal]
key = "nominal"
exposure_type = "pot"
trees = ["signal"]

[samples.signal.precompute]
no_photons_cut = "reco_photon_multiplicity == 0"
no_electrons_cut = "reco_electron_multiplicity == 0"
no_pions_cut = "reco_pion_multiplicity == 0"
single_muon_cut = "reco_muon_multiplicity == 1"
multiple_protons_cut = "reco_proton_multiplicity > 1"

[variables.true_neutrino_energy]
key = "true_neutrino_energy"
range = [0.4, 3.0]
nbins = 15
binning_scheme = "equal_width"
xlabel = "True Neutrino Energy [GeV]"

[variables.true_leading_muon_ke]
key = "true_leading_muon_ke"
range = [0, 1200]
nbins = 15
xlabel = "True muon KE [MeV]"

[[style]]
name = "icarus_1muNp"
style_sheet = "/Users/rvizarreta/Library/CloudStorage/GoogleDrive-rvizarreta14@gmail.com/My Drive/🏛 PhD Repository/🚀 Research/🤖 Experiments&Projects/ICARUS/ICARUS_CC0pi_Selection/ICARUS-NuMI-CC0pi-Selection/spineplot/styles/muon2024.mplstyle"
markers = ["o", "^", "s", "P", "D"]
default_figsize = [10, 8]
title = ""
mark_pot = true
mark_pot_horizontal = true
mark_preliminary = "ICARUS Work-in-Progress"
scilimits = [-3, 3]

[style.plot_kwargs]
histtype = "barstacked"
stacked = true

[analysis]
ordinate_sample = "signal"
category_branch = "true_category"
category_assignment = [[0.0]]
category_labels = ["1μNp0π Signal"]
category_colors = ["C0"]
category_types = ["histogram"]

[[figure]]
name = "icarus_sig_1muNp0pi_efficiency_table"
type = "SimpleFigure"
style = "icarus_1muNp"
figsize = [10.0, 6.0]

[[figure.artists]]
type = "SpineEfficiency"
variable = "true_neutrino_energy"
groups = ["1μNp0π Signal"]
draw_kwargs = {show_option = "table", percentage = true, show_seqeff = true, show_unseqeff = true, npts = 50000}

[figure.artists.cuts]
reco_fiducial_cut = "Fiducial"
single_muon_cut = "Single Muon"
multiple_protons_cut = "Multiple Protons"
no_pions_cut = "No Charged Pions"
no_photons_cut = "No Photons"
no_electrons_cut = "No Electrons"

[[figure]]
name = "icarus_sig_1muNp0pi_efficiency_plot"
type = "SimpleFigure"
style = "icarus_1muNp"
figsize = [10.0, 6.0]

[[figure.artists]]
type = "SpineEfficiency"
variable = "true_leading_muon_ke"
groups = ["1μNp0π Signal"]
draw_kwargs = {show_option = "differential", percentage = true, show_seqeff = true, show_unseqeff = false, npts = 50000}

[figure.artists.cuts]
reco_fiducial_cut = "Fiducial"
single_muon_cut = "Single Muon"
multiple_protons_cut = "Multiple Protons"
no_pions_cut = "No Charged Pions"
no_photons_cut = "No Photons"
no_electrons_cut = "No Electrons"
"""
# Write the string to a file
with open('cfg.toml', 'w') as f:
    f.write(cfg)

file = '/Users/rvizarreta/Library/CloudStorage/GoogleDrive-rvizarreta14@gmail.com/My Drive/🏛 PhD Repository/🚀 Research/🤖 Experiments&Projects/ICARUS/ICARUS_CC0pi_Selection/data/1muNp0pi_Nge2.root'
analysis = Analysis('cfg.toml', file)
analysis.run(close_figs=False)
# Out:
# Setting weight for signal to 1.00e+00

# %%
import uproot
import pandas as pd

with uproot.open(file) as f:
    # Load both trees
    signal_tree = f['events/nominal/signal']
    selected_tree = f['events/nominal/selected']

    signal_df = signal_tree.arrays(library='pd')
    selected_df = selected_tree.arrays(library='pd')

    print("=== Signal Tree ===")
    print(f"Total signal events: {len(signal_df)}")
    print("Categories:", signal_df['true_category'].value_counts().sort_index())

    print("\n=== Selected Tree ===")
    print(f"Total selected events: {len(selected_df)}")
    print("Categories:", selected_df['true_category'].value_counts().sort_index())

    # Calculate purity
    signal_in_selected = len(selected_df[selected_df['true_category'] == 0.0])
    total_selected = len(selected_df)

    purity = signal_in_selected / total_selected * 100
    print(f"\nPurity = {signal_in_selected}/{total_selected} = {purity:.1f}%")
# Out:
# === Signal Tree ===
# Total signal events: 7012
# Categories: true_category
# 0.0    7012
# Name: count, dtype: int64
#
# === Selected Tree ===
# Total selected events: 6605
# Categories: true_category
# 0.0    4965
# 1.0     535
# 2.0      43
# 3.0     927
# 4.0     125
# 6.0      10
# Name: count, dtype: int64
#
# Purity = 4965/6605 = 75.2%
