# %%
import toml
import os
import sys
workspace_root = os.getcwd()  
sys.path.insert(0, workspace_root + "/..")
from analysis import Analysis

# %%
# ANALYSIS SPECIFIC DIRECTORIES
ana_directory = "1muNp0pi_Nge1_uncontained"
#data_file = '/Users/rvizarreta/Library/CloudStorage/GoogleDrive-rvizarreta14@gmail.com/My Drive/🏛 PhD Repository/🚀 Research/🤖 Experiments&Projects/ICARUS/ICARUS_CC0pi_Selection/data/1muNp0pi_Nge1_uncontained.root'
data_file = '/Users/rvizarreta/Library/CloudStorage/GoogleDrive-rvizarreta14@gmail.com/My Drive/🏛 PhD Repository/🚀 Research/🤖 Experiments&Projects/ICARUS/ICARUS_CC0pi_Selection/data/icarus_numi_numu_mc_onbeam_offbeam_syst_ppfx.root'

# %%
# Delta p_T plots
analysis = Analysis(ana_directory + '/dpT/dpT.toml', data_file)
analysis.run(close_figs=False)
# Out:
# ============================================================
# Processing systematics for sample: mc
# ============================================================
# --Systematic(GENIEReWeight_SBN_v1_multisim_ZExpAVariationResponse, None)--
# 	Fractional uncertainty: 0.39%
# --Systematic(GENIEReWeight_SBN_v1_multisim_RPA_CCQE, None)--
# 	Fractional uncertainty: 0.15%
# --Systematic(GENIEReWeight_SBN_v1_multisim_CoulombCCQE, None)--
# 	Fractional uncertainty: 0.00%
# --Systematic(GENIEReWeight_SBN_v1_multisim_NormCCMEC, None)--
# 	Fractional uncertainty: 0.12%
# --Systematic(GENIEReWeight_SBN_v1_multisim_NormNCMEC, None)--
# 	Fractional uncertainty: 0.00%
# --Systematic(GENIEReWeight_SBN_v1_multisim_NCELVariationResponse, None)--
# 	Fractional uncertainty: 0.00%
# --Systematic(GENIEReWeight_SBN_v1_multisim_CCRESVariationResponse, None)--
# 	Fractional uncertainty: 0.79%
# --Systematic(GENIEReWeight_SBN_v1_multisim_NCRESVariationResponse, None)--
# 	Fractional uncertainty: 0.07%
# --Systematic(GENIEReWeight_SBN_v1_multisim_NonRESBGvpCC1pi, None)--
# 	Fractional uncertainty: 0.00%
# --Systematic(GENIEReWeight_SBN_v1_multisim_NonRESBGvpCC2pi, None)--
# 	Fractional uncertainty: 0.06%
# --Systematic(GENIEReWeight_SBN_v1_multisim_NonRESBGvpNC1pi, None)--
# 	Fractional uncertainty: 0.00%
# --Systematic(GENIEReWeight_SBN_v1_multisim_NonRESBGvpNC2pi, None)--
# 	Fractional uncertainty: 0.00%
# --Systematic(GENIEReWeight_SBN_v1_multisim_NonRESBGvnCC1pi, None)--
# 	Fractional uncertainty: 0.03%
# --Systematic(GENIEReWeight_SBN_v1_multisim_NonRESBGvnCC2pi, None)--
# 	Fractional uncertainty: 0.05%
# --Systematic(GENIEReWeight_SBN_v1_multisim_NonRESBGvnNC1pi, None)--
# 	Fractional uncertainty: 0.02%
# --Systematic(GENIEReWeight_SBN_v1_multisim_NonRESBGvnNC2pi, None)--
# 	Fractional uncertainty: 0.00%
# --Systematic(GENIEReWeight_SBN_v1_multisim_NonRESBGvbarpCC1pi, None)--
# 	Fractional uncertainty: 0.01%
# --Systematic(GENIEReWeight_SBN_v1_multisim_NonRESBGvbarpCC2pi, None)--
# 	Fractional uncertainty: 0.02%
# --Systematic(GENIEReWeight_SBN_v1_multisim_NonRESBGvbarpNC1pi, None)--
# 	Fractional uncertainty: 0.00%
# --Systematic(GENIEReWeight_SBN_v1_multisim_NonRESBGvbarpNC2pi, None)--
# 	Fractional uncertainty: 0.00%
# --Systematic(GENIEReWeight_SBN_v1_multisim_NonRESBGvbarnCC1pi, None)--
# 	Fractional uncertainty: 0.01%
# --Systematic(GENIEReWeight_SBN_v1_multisim_NonRESBGvbarnCC2pi, None)--
# 	Fractional uncertainty: 0.05%
# --Systematic(GENIEReWeight_SBN_v1_multisim_NonRESBGvbarnNC1pi, None)--
# 	Fractional uncertainty: 0.00%
# --Systematic(GENIEReWeight_SBN_v1_multisim_NonRESBGvbarnNC2pi, None)--
# 	Fractional uncertainty: 0.00%
# --Systematic(GENIEReWeight_SBN_v1_multisim_RDecBR1gamma, None)--
# 	Fractional uncertainty: 0.00%
# --Systematic(GENIEReWeight_SBN_v1_multisim_RDecBR1eta, None)--
# 	Fractional uncertainty: 0.04%
# --Systematic(GENIEReWeight_SBN_v1_multisim_COHVariationResponse, None)--
# 	Fractional uncertainty: 0.00%
# --Systematic(GENIEReWeight_SBN_v1_multisim_DISBYVariationResponse, None)--
# 	Fractional uncertainty: 0.00%
# --Systematic(GENIEReWeight_SBN_v1_multisim_FSI_pi_VariationResponse, None)--
# 	Fractional uncertainty: 0.25%
# --Systematic(GENIEReWeight_SBN_v1_multisim_FSI_N_VariationResponse, None)--
# 	Fractional uncertainty: 0.06%
# --Systematic(MINERvAE2p2h_SBN_v1_E2p2h_A_nu, None)--
# 	Fractional uncertainty: 0.06%
# --Systematic(MINERvAE2p2h_SBN_v1_E2p2h_B_nu, None)--
# 	Fractional uncertainty: 0.03%
# --Systematic(MINERvAE2p2h_SBN_v1_E2p2h_A_nubar, None)--
# 	Fractional uncertainty: 0.02%
# --Systematic(MINERvAE2p2h_SBN_v1_E2p2h_B_nubar, None)--
# 	Fractional uncertainty: 0.00%
# --Systematic(MINERvAg0q3Weighting_SBN_v1_Mnv202hGaussEnhancement, None)--
# 	Fractional uncertainty: 0.03%
# --Systematic(MiscInteractionSysts_SBN_v1_C12ToAr40_2p2hScaling_nu, None)--
# 	Fractional uncertainty: 0.04%
# --Systematic(MiscInteractionSysts_SBN_v1_C12ToAr40_2p2hScaling_nubar, None)--
# 	Fractional uncertainty: 0.01%
# --Systematic(MiscInteractionSysts_SBN_v1_nuenuebar_xsec_ratio, None)--
# 	Fractional uncertainty: 0.00%
# --Systematic(MiscInteractionSysts_SBN_v1_nuenumu_xsec_ratio, None)--
# 	Fractional uncertainty: 0.00%
# --Systematic(MiscInteractionSysts_SBN_v1_SPPLowQ2Suppression, None)--
# 	Fractional uncertainty: 0.37%
# --Systematic(NOvAStyleNonResPionNorm_SBN_v1_NR_nu_n_CC_2Pi, None)--
# 	Fractional uncertainty: 0.05%
# --Systematic(NOvAStyleNonResPionNorm_SBN_v1_NR_nu_n_CC_3Pi, None)--
# 	Fractional uncertainty: 0.00%
# --Systematic(NOvAStyleNonResPionNorm_SBN_v1_NR_nu_p_CC_2Pi, None)--
# 	Fractional uncertainty: 0.05%
# --Systematic(NOvAStyleNonResPionNorm_SBN_v1_NR_nu_p_CC_3Pi, None)--
# 	Fractional uncertainty: 0.01%
# --Systematic(NOvAStyleNonResPionNorm_SBN_v1_NR_nu_np_CC_1Pi, None)--
# 	Fractional uncertainty: 0.04%
# --Systematic(NOvAStyleNonResPionNorm_SBN_v1_NR_nu_n_NC_1Pi, None)--
# 	Fractional uncertainty: 0.02%
# --Systematic(NOvAStyleNonResPionNorm_SBN_v1_NR_nu_n_NC_2Pi, None)--
# 	Fractional uncertainty: 0.00%
# --Systematic(NOvAStyleNonResPionNorm_SBN_v1_NR_nu_n_NC_3Pi, None)--
# 	Fractional uncertainty: 0.00%
# --Systematic(NOvAStyleNonResPionNorm_SBN_v1_NR_nu_p_NC_1Pi, None)--
# 	Fractional uncertainty: 0.00%
# --Systematic(NOvAStyleNonResPionNorm_SBN_v1_NR_nu_p_NC_2Pi, None)--
# 	Fractional uncertainty: 0.00%
# --Systematic(NOvAStyleNonResPionNorm_SBN_v1_NR_nu_p_NC_3Pi, None)--
# 	Fractional uncertainty: 0.00%
# --Systematic(NOvAStyleNonResPionNorm_SBN_v1_NR_nubar_n_CC_1Pi, None)--
# 	Fractional uncertainty: 0.01%
# --Systematic(NOvAStyleNonResPionNorm_SBN_v1_NR_nubar_n_CC_2Pi, None)--
# 	Fractional uncertainty: 0.04%
# --Systematic(NOvAStyleNonResPionNorm_SBN_v1_NR_nubar_n_CC_3Pi, None)--
# 	Fractional uncertainty: 0.01%
# --Systematic(NOvAStyleNonResPionNorm_SBN_v1_NR_nubar_p_CC_1Pi, None)--
# 	Fractional uncertainty: 0.01%
# --Systematic(NOvAStyleNonResPionNorm_SBN_v1_NR_nubar_p_CC_2Pi, None)--
# 	Fractional uncertainty: 0.02%
# --Systematic(NOvAStyleNonResPionNorm_SBN_v1_NR_nubar_p_CC_3Pi, None)--
# 	Fractional uncertainty: 0.00%
# --Systematic(NOvAStyleNonResPionNorm_SBN_v1_NR_nubar_n_NC_1Pi, None)--
# 	Fractional uncertainty: 0.00%
# --Systematic(NOvAStyleNonResPionNorm_SBN_v1_NR_nubar_n_NC_2Pi, None)--
# 	Fractional uncertainty: 0.00%
# --Systematic(NOvAStyleNonResPionNorm_SBN_v1_NR_nubar_n_NC_3Pi, None)--
# 	Fractional uncertainty: 0.00%
# --Systematic(NOvAStyleNonResPionNorm_SBN_v1_NR_nubar_p_NC_1Pi, None)--
# 	Fractional uncertainty: 0.00%
# --Systematic(NOvAStyleNonResPionNorm_SBN_v1_NR_nubar_p_NC_2Pi, None)--
# 	Fractional uncertainty: 0.00%
# --Systematic(NOvAStyleNonResPionNorm_SBN_v1_NR_nubar_p_NC_3Pi, None)--
# 	Fractional uncertainty: 0.00%
# --Systematic(expskin_Flux, None)--
# 	Fractional uncertainty: 0.05%
# --Systematic(horncurrent_Flux, None)--
# 	Fractional uncertainty: 0.01%
# --Systematic(kminus_Flux, None)--
# 	Fractional uncertainty: 0.25%
# --Systematic(kplus_Flux, None)--
# 	Fractional uncertainty: 0.07%
# --Systematic(kzero_Flux, None)--
# 	Fractional uncertainty: 0.05%
# --Systematic(nucleoninexsec_Flux, None)--
# 	Fractional uncertainty: 0.04%
# --Systematic(nucleonqexsec_Flux, None)--
# 	Fractional uncertainty: 0.14%
# --Systematic(nucleontotxsec_Flux, None)--
# 	Fractional uncertainty: 0.04%
# --Systematic(piminus_Flux, None)--
# 	Fractional uncertainty: 0.03%
# --Systematic(pioninexsec_Flux, None)--
# 	Fractional uncertainty: 0.02%
# --Systematic(pionqexsec_Flux, None)--
# 	Fractional uncertainty: 0.01%
# --Systematic(piontotxsec_Flux, None)--
# 	Fractional uncertainty: 0.03%
# --Systematic(piplus_Flux, None)--
# 	Fractional uncertainty: 0.14%
# --Systematic(GENIEReWeight_SBN_v1_multisigma_ZExpA1CCQE, None)--
# 	Fractional uncertainty: 0.32%
# --Systematic(GENIEReWeight_SBN_v1_multisigma_ZExpA1CCQE_sigma, None)--
# 	Fractional uncertainty: 6.14%
# --Systematic(GENIEReWeight_SBN_v1_multisigma_ZExpA2CCQE, None)--
# 	Fractional uncertainty: 0.01%
# --Systematic(GENIEReWeight_SBN_v1_multisigma_ZExpA2CCQE_sigma, None)--
# 	Fractional uncertainty: 6.23%
# --Systematic(GENIEReWeight_SBN_v1_multisigma_ZExpA3CCQE, None)--
# 	Fractional uncertainty: 0.22%
# --Systematic(GENIEReWeight_SBN_v1_multisigma_ZExpA3CCQE_sigma, None)--
# 	Fractional uncertainty: 6.17%
# --Systematic(GENIEReWeight_SBN_v1_multisigma_ZExpA4CCQE, None)--
# 	Fractional uncertainty: 0.01%
# --Systematic(GENIEReWeight_SBN_v1_multisigma_ZExpA4CCQE_sigma, None)--
# 	Fractional uncertainty: 6.24%
# --Systematic(GENIEReWeight_SBN_v1_multisigma_VecFFCCQEshape, None)--
# 	Fractional uncertainty: 0.04%
# --Systematic(GENIEReWeight_SBN_v1_multisigma_VecFFCCQEshape_sigma, None)--
# 	Fractional uncertainty: 6.22%
# --Systematic(GENIEReWeight_SBN_v1_multisigma_RPA_CCQE, None)--
# 	Fractional uncertainty: 0.11%
# --Systematic(GENIEReWeight_SBN_v1_multisigma_RPA_CCQE_sigma, None)--
# 	Fractional uncertainty: 6.09%
# --Systematic(GENIEReWeight_SBN_v1_multisigma_CoulombCCQE, None)--
# 	Fractional uncertainty: 0.00%
# --Systematic(GENIEReWeight_SBN_v1_multisigma_CoulombCCQE_sigma, None)--
# 	Fractional uncertainty: 6.18%
# --Systematic(GENIEReWeight_SBN_v1_multisigma_NormCCMEC, None)--
# 	Fractional uncertainty: 0.10%
# --Systematic(GENIEReWeight_SBN_v1_multisigma_NormCCMEC_sigma, None)--
# 	Fractional uncertainty: 6.14%
# --Systematic(GENIEReWeight_SBN_v1_multisigma_NormNCMEC, None)--
# 	Fractional uncertainty: 0.00%
# --Systematic(GENIEReWeight_SBN_v1_multisigma_NormNCMEC_sigma, None)--
# 	Fractional uncertainty: 6.12%
# --Systematic(GENIEReWeight_SBN_v1_multisigma_DecayAngMEC, None)--
# 	Fractional uncertainty: 0.06%
# --Systematic(GENIEReWeight_SBN_v1_multisigma_DecayAngMEC_sigma, None)--
# 	Fractional uncertainty: 6.12%
# --Systematic(GENIEReWeight_SBN_v1_multisigma_MaNCEL, None)--
# 	Fractional uncertainty: 0.00%
# --Systematic(GENIEReWeight_SBN_v1_multisigma_MaNCEL_sigma, None)--
# 	Fractional uncertainty: 6.14%
# --Systematic(GENIEReWeight_SBN_v1_multisigma_EtaNCEL, None)--
# 	Fractional uncertainty: 0.00%
# --Systematic(GENIEReWeight_SBN_v1_multisigma_EtaNCEL_sigma, None)--
# 	Fractional uncertainty: 5.96%
# --Systematic(GENIEReWeight_SBN_v1_multisigma_MaCCRES, None)--
# 	Fractional uncertainty: 0.52%
# --Systematic(GENIEReWeight_SBN_v1_multisigma_MaCCRES_sigma, None)--
# 	Fractional uncertainty: 6.11%
# --Systematic(GENIEReWeight_SBN_v1_multisigma_MvCCRES, None)--
# 	Fractional uncertainty: 0.50%
# --Systematic(GENIEReWeight_SBN_v1_multisigma_MvCCRES_sigma, None)--
# 	Fractional uncertainty: 6.18%
# --Systematic(GENIEReWeight_SBN_v1_multisigma_MaNCRES, None)--
# 	Fractional uncertainty: 0.06%
# --Systematic(GENIEReWeight_SBN_v1_multisigma_MaNCRES_sigma, None)--
# 	Fractional uncertainty: 6.10%
# --Systematic(GENIEReWeight_SBN_v1_multisigma_MvNCRES, None)--
# 	Fractional uncertainty: 0.02%
# --Systematic(GENIEReWeight_SBN_v1_multisigma_MvNCRES_sigma, None)--
# 	Fractional uncertainty: 6.13%
# --Systematic(GENIEReWeight_SBN_v1_multisigma_NonRESBGvpCC1pi, None)--
# 	Fractional uncertainty: 0.00%
# --Systematic(GENIEReWeight_SBN_v1_multisigma_NonRESBGvpCC1pi_sigma, None)--
# 	Fractional uncertainty: 6.05%
# --Systematic(GENIEReWeight_SBN_v1_multisigma_NonRESBGvpCC2pi, None)--
# 	Fractional uncertainty: 0.05%
# --Systematic(GENIEReWeight_SBN_v1_multisigma_NonRESBGvpCC2pi_sigma, None)--
# 	Fractional uncertainty: 6.19%
# --Systematic(GENIEReWeight_SBN_v1_multisigma_NonRESBGvpNC1pi, None)--
# 	Fractional uncertainty: 0.00%
# --Systematic(GENIEReWeight_SBN_v1_multisigma_NonRESBGvpNC1pi_sigma, None)--
# 	Fractional uncertainty: 6.04%
# --Systematic(GENIEReWeight_SBN_v1_multisigma_NonRESBGvpNC2pi, None)--
# 	Fractional uncertainty: 0.00%
# --Systematic(GENIEReWeight_SBN_v1_multisigma_NonRESBGvpNC2pi_sigma, None)--
# 	Fractional uncertainty: 6.06%
# --Systematic(GENIEReWeight_SBN_v1_multisigma_NonRESBGvnCC1pi, None)--
# 	Fractional uncertainty: 0.02%
# --Systematic(GENIEReWeight_SBN_v1_multisigma_NonRESBGvnCC1pi_sigma, None)--
# 	Fractional uncertainty: 6.23%
# --Systematic(GENIEReWeight_SBN_v1_multisigma_NonRESBGvnCC2pi, None)--
# 	Fractional uncertainty: 0.05%
# --Systematic(GENIEReWeight_SBN_v1_multisigma_NonRESBGvnCC2pi_sigma, None)--
# 	Fractional uncertainty: 6.07%
# --Systematic(GENIEReWeight_SBN_v1_multisigma_NonRESBGvnNC1pi, None)--
# 	Fractional uncertainty: 0.02%
# --Systematic(GENIEReWeight_SBN_v1_multisigma_NonRESBGvnNC1pi_sigma, None)--
# 	Fractional uncertainty: 6.25%
# --Systematic(GENIEReWeight_SBN_v1_multisigma_NonRESBGvnNC2pi, None)--
# 	Fractional uncertainty: 0.00%
# --Systematic(GENIEReWeight_SBN_v1_multisigma_NonRESBGvnNC2pi_sigma, None)--
# 	Fractional uncertainty: 6.05%
# --Systematic(GENIEReWeight_SBN_v1_multisigma_NonRESBGvbarpCC1pi, None)--
# 	Fractional uncertainty: 0.01%
# --Systematic(GENIEReWeight_SBN_v1_multisigma_NonRESBGvbarpCC1pi_sigma, None)--
# 	Fractional uncertainty: 5.90%
# --Systematic(GENIEReWeight_SBN_v1_multisigma_NonRESBGvbarpCC2pi, None)--
# 	Fractional uncertainty: 0.02%
# --Systematic(GENIEReWeight_SBN_v1_multisigma_NonRESBGvbarpCC2pi_sigma, None)--
# 	Fractional uncertainty: 6.10%
# --Systematic(GENIEReWeight_SBN_v1_multisigma_NonRESBGvbarpNC1pi, None)--
# 	Fractional uncertainty: 0.00%
# --Systematic(GENIEReWeight_SBN_v1_multisigma_NonRESBGvbarpNC1pi_sigma, None)--
# 	Fractional uncertainty: 6.18%
# --Systematic(GENIEReWeight_SBN_v1_multisigma_NonRESBGvbarpNC2pi, None)--
# 	Fractional uncertainty: 0.00%
# --Systematic(GENIEReWeight_SBN_v1_multisigma_NonRESBGvbarpNC2pi_sigma, None)--
# 	Fractional uncertainty: 6.14%
# --Systematic(GENIEReWeight_SBN_v1_multisigma_NonRESBGvbarnCC1pi, None)--
# 	Fractional uncertainty: 0.01%
# --Systematic(GENIEReWeight_SBN_v1_multisigma_NonRESBGvbarnCC1pi_sigma, None)--
# 	Fractional uncertainty: 6.15%
# --Systematic(GENIEReWeight_SBN_v1_multisigma_NonRESBGvbarnCC2pi, None)--
# 	Fractional uncertainty: 0.04%
# --Systematic(GENIEReWeight_SBN_v1_multisigma_NonRESBGvbarnCC2pi_sigma, None)--
# 	Fractional uncertainty: 5.94%
# --Systematic(GENIEReWeight_SBN_v1_multisigma_NonRESBGvbarnNC1pi, None)--
# 	Fractional uncertainty: 0.00%
# --Systematic(GENIEReWeight_SBN_v1_multisigma_NonRESBGvbarnNC1pi_sigma, None)--
# 	Fractional uncertainty: 6.16%
# --Systematic(GENIEReWeight_SBN_v1_multisigma_NonRESBGvbarnNC2pi, None)--
# 	Fractional uncertainty: 0.00%
# --Systematic(GENIEReWeight_SBN_v1_multisigma_NonRESBGvbarnNC2pi_sigma, None)--
# 	Fractional uncertainty: 6.30%
# --Systematic(GENIEReWeight_SBN_v1_multisigma_RDecBR1gamma, None)--
# 	Fractional uncertainty: 0.00%
# --Systematic(GENIEReWeight_SBN_v1_multisigma_RDecBR1gamma_sigma, None)--
# 	Fractional uncertainty: 6.14%
# --Systematic(GENIEReWeight_SBN_v1_multisigma_RDecBR1eta, None)--
# 	Fractional uncertainty: 0.03%
# --Systematic(GENIEReWeight_SBN_v1_multisigma_RDecBR1eta_sigma, None)--
# 	Fractional uncertainty: 6.15%
# --Systematic(GENIEReWeight_SBN_v1_multisigma_Theta_Delta2Npi, None)--
# 	Fractional uncertainty: 0.10%
# --Systematic(GENIEReWeight_SBN_v1_multisigma_Theta_Delta2Npi_sigma, None)--
# 	Fractional uncertainty: 6.03%
# --Systematic(GENIEReWeight_SBN_v1_multisigma_ThetaDelta2NRad, None)--
# 	Fractional uncertainty: 0.00%
# --Systematic(GENIEReWeight_SBN_v1_multisigma_ThetaDelta2NRad_sigma, None)--
# 	Fractional uncertainty: 6.06%
# --Systematic(GENIEReWeight_SBN_v1_multisigma_NormCCCOH, None)--
# 	Fractional uncertainty: 0.00%
# --Systematic(GENIEReWeight_SBN_v1_multisigma_NormCCCOH_sigma, None)--
# 	Fractional uncertainty: 6.16%
# --Systematic(GENIEReWeight_SBN_v1_multisigma_NormNCCOH, None)--
# 	Fractional uncertainty: 0.00%
# --Systematic(GENIEReWeight_SBN_v1_multisigma_NormNCCOH_sigma, None)--
# 	Fractional uncertainty: 6.11%
# --Systematic(GENIEReWeight_SBN_v1_multisigma_AhtBY, None)--
# 	Fractional uncertainty: 0.00%
# --Systematic(GENIEReWeight_SBN_v1_multisigma_AhtBY_sigma, None)--
# 	Fractional uncertainty: 6.28%
# --Systematic(GENIEReWeight_SBN_v1_multisigma_BhtBY, None)--
# 	Fractional uncertainty: 0.00%
# --Systematic(GENIEReWeight_SBN_v1_multisigma_BhtBY_sigma, None)--
# 	Fractional uncertainty: 6.27%
# --Systematic(GENIEReWeight_SBN_v1_multisigma_CV1uBY, None)--
# 	Fractional uncertainty: 0.00%
# --Systematic(GENIEReWeight_SBN_v1_multisigma_CV1uBY_sigma, None)--
# 	Fractional uncertainty: 6.05%
# --Systematic(GENIEReWeight_SBN_v1_multisigma_CV2uBY, None)--
# 	Fractional uncertainty: 0.00%
# --Systematic(GENIEReWeight_SBN_v1_multisigma_CV2uBY_sigma, None)--
# 	Fractional uncertainty: 6.04%
# --Systematic(GENIEReWeight_SBN_v1_multisigma_MFP_pi, None)--
# 	Fractional uncertainty: 0.01%
# --Systematic(GENIEReWeight_SBN_v1_multisigma_MFP_pi_sigma, None)--
# 	Fractional uncertainty: 6.17%
# --Systematic(GENIEReWeight_SBN_v1_multisigma_FrCEx_pi, None)--
# 	Fractional uncertainty: 0.12%
# --Systematic(GENIEReWeight_SBN_v1_multisigma_FrCEx_pi_sigma, None)--
# 	Fractional uncertainty: 6.14%
# --Systematic(GENIEReWeight_SBN_v1_multisigma_FrInel_pi, None)--
# 	Fractional uncertainty: 0.24%
# --Systematic(GENIEReWeight_SBN_v1_multisigma_FrInel_pi_sigma, None)--
# 	Fractional uncertainty: 6.05%
# --Systematic(GENIEReWeight_SBN_v1_multisigma_FrAbs_pi, None)--
# 	Fractional uncertainty: 0.16%
# --Systematic(GENIEReWeight_SBN_v1_multisigma_FrAbs_pi_sigma, None)--
# 	Fractional uncertainty: 6.02%
# --Systematic(GENIEReWeight_SBN_v1_multisigma_FrPiProd_pi, None)--
# 	Fractional uncertainty: 0.03%
# --Systematic(GENIEReWeight_SBN_v1_multisigma_FrPiProd_pi_sigma, None)--
# 	Fractional uncertainty: 6.12%
# --Systematic(GENIEReWeight_SBN_v1_multisigma_MFP_N, None)--
# 	Fractional uncertainty: 0.00%
# --Systematic(GENIEReWeight_SBN_v1_multisigma_MFP_N_sigma, None)--
# 	Fractional uncertainty: 6.37%
# --Systematic(GENIEReWeight_SBN_v1_multisigma_FrCEx_N, None)--
# 	Fractional uncertainty: 0.01%
# --Systematic(GENIEReWeight_SBN_v1_multisigma_FrCEx_N_sigma, None)--
# 	Fractional uncertainty: 6.09%
# --Systematic(GENIEReWeight_SBN_v1_multisigma_FrInel_N, None)--
# 	Fractional uncertainty: 0.02%
# --Systematic(GENIEReWeight_SBN_v1_multisigma_FrInel_N_sigma, None)--
# 	Fractional uncertainty: 6.09%
# --Systematic(GENIEReWeight_SBN_v1_multisigma_FrAbs_N, None)--
# 	Fractional uncertainty: 0.03%
# --Systematic(GENIEReWeight_SBN_v1_multisigma_FrAbs_N_sigma, None)--
# 	Fractional uncertainty: 6.13%
# --Systematic(GENIEReWeight_SBN_v1_multisigma_FrPiProd_N, None)--
# 	Fractional uncertainty: 0.04%
# --Systematic(GENIEReWeight_SBN_v1_multisigma_FrPiProd_N_sigma, None)--
# 	Fractional uncertainty: 5.98%
# --Systematic(hysyst_beam_horn_2kA, None)--
# 	Fractional uncertainty: 0.01%
# --Systematic(hysyst_beam_horn1_x_3mm, None)--
# 	Fractional uncertainty: 0.00%
# --Systematic(hysyst_beam_horn1_y_3mm, None)--
# 	Fractional uncertainty: 0.02%
# --Systematic(hysyst_beam_spot_1_3mm, None)--
# 	Fractional uncertainty: 0.07%
# --Systematic(hysyst_beam_spot_1_7mm, None)--
# 	Fractional uncertainty: 0.11%
# --Systematic(hysyst_beam_horn2_x_3mm, None)--
# 	Fractional uncertainty: 0.00%
# --Systematic(hysyst_beam_horn2_y_3mm, None)--
# 	Fractional uncertainty: 0.00%
# --Systematic(hysyst_beam_horns_0mm_water, None)--
# 	Fractional uncertainty: 0.00%
# --Systematic(hysyst_beam_horns_2mm_water, None)--
# 	Fractional uncertainty: 0.01%
# --Systematic(hysyst_beam_Beam_shift_x_1mm, None)--
# 	Fractional uncertainty: 0.10%
# --Systematic(hysyst_beam_Beam_shift_y_1mm, None)--
# 	Fractional uncertainty: 0.09%
# --Systematic(hysyst_beam_Target_z_7mm, None)--
# 	Fractional uncertainty: 0.01%
# --Systematic(hysyst_hpc_0, None)--
# 	Fractional uncertainty: 0.20%
# --Systematic(hysyst_hpc_1, None)--
# 	Fractional uncertainty: 0.11%
# --Systematic(hysyst_hpc_2, None)--
# 	Fractional uncertainty: 0.09%
# --Systematic(hysyst_hpc_3, None)--
# 	Fractional uncertainty: 0.02%
# --Systematic(hysyst_hpc_4, None)--
# 	Fractional uncertainty: 0.15%
# --Systematic(hysyst_hpc_5, None)--
# 	Fractional uncertainty: 0.12%
# --Systematic(hysyst_hpc_6, None)--
# 	Fractional uncertainty: 0.02%
# --Systematic(hysyst_hpc_7, None)--
# 	Fractional uncertainty: 0.05%
# --Systematic(hysyst_hpc_8, None)--
# 	Fractional uncertainty: 0.08%
# --Systematic(hysyst_hpc_9, None)--
# 	Fractional uncertainty: 0.02%
# --Systematic(hysyst_hpc_10, None)--
# 	Fractional uncertainty: 0.01%
# --Systematic(hysyst_hpc_11, None)--
# 	Fractional uncertainty: 0.00%
# --Systematic(hysyst_hpc_12, None)--
# 	Fractional uncertainty: 0.01%
# --Systematic(hysyst_hpc_13, None)--
# 	Fractional uncertainty: 0.00%
# --Systematic(hysyst_hpc_14, None)--
# 	Fractional uncertainty: 0.00%
# --Systematic(hysyst_beam_horn_2kA_sigma, None)--
# 	Fractional uncertainty: 7.24%
# --Systematic(hysyst_beam_horn1_x_3mm_sigma, None)--
# 	Fractional uncertainty: 6.98%
# --Systematic(hysyst_beam_horn1_y_3mm_sigma, None)--
# 	Fractional uncertainty: 6.76%
# --Systematic(hysyst_beam_spot_1_3mm_sigma, None)--
# 	Fractional uncertainty: 7.04%
# --Systematic(hysyst_beam_spot_1_7mm_sigma, None)--
# 	Fractional uncertainty: 6.85%
# --Systematic(hysyst_beam_horn2_x_3mm_sigma, None)--
# 	Fractional uncertainty: 6.69%
# --Systematic(hysyst_beam_horn2_y_3mm_sigma, None)--
# 	Fractional uncertainty: 7.12%
# --Systematic(hysyst_beam_horns_0mm_water_sigma, None)--
# 	Fractional uncertainty: 7.13%
# --Systematic(hysyst_beam_horns_2mm_water_sigma, None)--
# 	Fractional uncertainty: 6.79%
# --Systematic(hysyst_beam_Beam_shift_x_1mm_sigma, None)--
# 	Fractional uncertainty: 6.91%
# --Systematic(hysyst_beam_Beam_shift_y_1mm_sigma, None)--
# 	Fractional uncertainty: 6.88%
# --Systematic(hysyst_beam_Target_z_7mm_sigma, None)--
# 	Fractional uncertainty: 6.94%
# --Systematic(hysyst_hpc_0_sigma, None)--
# 	Fractional uncertainty: 6.89%
# --Systematic(hysyst_hpc_1_sigma, None)--
# 	Fractional uncertainty: 7.15%
# --Systematic(hysyst_hpc_2_sigma, None)--
# 	Fractional uncertainty: 6.91%
# --Systematic(hysyst_hpc_3_sigma, None)--
# 	Fractional uncertainty: 6.89%
# --Systematic(hysyst_hpc_4_sigma, None)--
# 	Fractional uncertainty: 6.75%
# --Systematic(hysyst_hpc_5_sigma, None)--
# 	Fractional uncertainty: 6.68%
# --Systematic(hysyst_hpc_6_sigma, None)--
# 	Fractional uncertainty: 6.69%
# --Systematic(hysyst_hpc_7_sigma, None)--
# 	Fractional uncertainty: 7.03%
# --Systematic(hysyst_hpc_8_sigma, None)--
# 	Fractional uncertainty: 6.95%
# --Systematic(hysyst_hpc_9_sigma, None)--
# 	Fractional uncertainty: 6.88%
# --Systematic(hysyst_hpc_10_sigma, None)--
# 	Fractional uncertainty: 6.97%
# --Systematic(hysyst_hpc_11_sigma, None)--
# 	Fractional uncertainty: 7.10%
# --Systematic(hysyst_hpc_12_sigma, None)--
# 	Fractional uncertainty: 7.04%
# --Systematic(hysyst_hpc_13_sigma, None)--
# 	Fractional uncertainty: 6.73%
# --Systematic(hysyst_hpc_14_sigma, None)--
# 	Fractional uncertainty: 6.92%
# --Systematic(statistical, None)--
# 	Fractional uncertainty: 3.08%
# --Systematic(stats, Stat.)--
# 	Fractional uncertainty: 3.08%
# --Systematic(flux, Flux)--
# 	Fractional uncertainty: 0.38%
# --Systematic(xsec, Cross-section)--
# 	Fractional uncertainty: 0.91%
# --Systematic(MC_total, Stats, Flux & Interaction Uncertainty)--
# 	Fractional uncertainty: 3.23%
#
# ============================================================
# Processing systematics for sample: onbeam
# ============================================================
# Setting weight for mc to 1.51e-01
# Setting weight for onbeam to 1.00e+00
# Fractional - Min: 8.18%, Max: 8.88%
# Fractional - Min: 12.56%, Max: 34.78%
# Fractional - Min: 1.91%, Max: 12.91%

# %%
import uproot

rf = uproot.open(data_file)
rf.keys()
# Check selected tree
print("selected:", rf['events/full/selected'].num_entries)

# Check systematic trees
print("multisim:", rf['events/full/selected_multisimTree'].num_entries)
print("multisigma:", rf['events/full/selected_multisigmaTree'].num_entries)

for key in rf.keys(recursive=True):
    if 'selected' in key.lower() or 'Tree' in key:
        try:
            print(f"{key}: {rf[key].num_entries}")
        except:
            pass
# Out:
# selected: 21720
# multisim: 21720
# multisigma: 21720
# events/full/selected_multisigmaTree;22: 21720
# events/full/selected_multisigmaTree;21: 21000
# events/full/selected_multisimTree;22: 21720
# events/full/selected_multisimTree;21: 21000
# events/full/selected_variationTree;6: 21720
# events/full/selected_variationTree;5: 20000
# events/full/selected_nonmatched;1: 18
# events/full/sideband_multisigmaTree;7: 6987
# events/full/sideband_multisigmaTree;6: 6000
# events/full/sideband_multisimTree;7: 6987
# events/full/sideband_multisimTree;6: 6000
# events/full/sideband_variationTree;2: 6987
# events/full/sideband_variationTree;1: 4000
# events/full/signal_multisigmaTree;30: 29069
# events/full/signal_multisigmaTree;29: 29000
# events/full/signal_multisimTree;30: 29069
# events/full/signal_multisimTree;29: 29000
# events/full/signal_variationTree;8: 29069
# events/full/signal_variationTree;7: 28000
# events/full/selected;1: 21720
# events/full/selected_NuMIfluxsimTree;1: 29069
# events/onbeam/selected;1: 3468

# %%
# Delta phiT plots
analysis = Analysis(ana_directory + '/dphiT/dphiT.toml', data_file)
analysis.run(close_figs=False)
# Out:
# ============================================================
# Processing systematics for sample: mc
# ============================================================
#
# ============================================================
# Processing systematics for sample: onbeam
# ============================================================
# Setting weight for mc to 1.51e-01
# Setting weight for onbeam to 1.00e+00
# Fractional - Min: 7.68%, Max: 8.37%
# Fractional - Min: 13.50%, Max: 21.41%
# Fractional - Min: 1.47%, Max: 7.81%

# %%
# Delta alpha_T plots
analysis = Analysis(ana_directory + '/dalphaT/dalphaT.toml', data_file)
analysis.run(close_figs=False)
# Out:
# ============================================================
# Processing systematics for sample: mc
# ============================================================
#
# ============================================================
# Processing systematics for sample: onbeam
# ============================================================
# Setting weight for mc to 1.51e-01
# Setting weight for onbeam to 1.00e+00
# Fractional - Min: 8.10%, Max: 8.42%
# Fractional - Min: 13.31%, Max: 20.43%
# Fractional - Min: 2.05%, Max: 4.35%

# %%
# Leading Muon Momentum
analysis = Analysis(ana_directory + '/leading_muon_momentum/leading_muon_momentum.toml', data_file)
analysis.run(close_figs=False)
# Out:
# ============================================================
# Processing systematics for sample: mc
# ============================================================
#
# ============================================================
# Processing systematics for sample: onbeam
# ============================================================
# Setting weight for mc to 1.51e-01
# Setting weight for onbeam to 1.00e+00
# Fractional - Min: 8.11%, Max: 9.87%
# Fractional - Min: 14.21%, Max: 30.03%
# Fractional - Min: 1.32%, Max: 40.82%

# %%
# Leading Muon Length
analysis = Analysis(ana_directory + '/leading_muon_length/leading_muon_length.toml', data_file)
analysis.run(close_figs=False)
# Out:
# ============================================================
# Processing systematics for sample: mc
# ============================================================
#
# ============================================================
# Processing systematics for sample: onbeam
# ============================================================
# Setting weight for mc to 1.51e-01
# Setting weight for onbeam to 1.00e+00
# Fractional - Min: 8.25%, Max: 8.84%
# Fractional - Min: 14.10%, Max: 17.76%
# Fractional - Min: 2.35%, Max: 7.07%

# %%
# Leading muon polar angle plots
analysis = Analysis(ana_directory + '/leading_muon_polar_angle/leading_muon_polar_angle.toml', data_file)
analysis.run(close_figs=False)
# Out:
# ============================================================
# Processing systematics for sample: mc
# ============================================================
#
# ============================================================
# Processing systematics for sample: onbeam
# ============================================================
# Setting weight for mc to 1.51e-01
# Setting weight for onbeam to 1.00e+00
# Fractional - Min: 8.05%, Max: 9.23%
# Fractional - Min: 15.43%, Max: 23.32%
# Fractional - Min: 1.43%, Max: 10.31%

# %%
# Leading Proton Momentum
analysis = Analysis(ana_directory + '/leading_proton_momentum/leading_proton_momentum.toml', data_file)
analysis.run(close_figs=False)
# Out:
# ============================================================
# Processing systematics for sample: mc
# ============================================================
# --Systematic(GENIEReWeight_SBN_v1_multisim_ZExpAVariationResponse, None)--
# 	Fractional uncertainty: 10.09%
# --Systematic(GENIEReWeight_SBN_v1_multisim_RPA_CCQE, None)--
# 	Fractional uncertainty: 0.97%
# --Systematic(GENIEReWeight_SBN_v1_multisim_CoulombCCQE, None)--
# 	Fractional uncertainty: 0.26%
# --Systematic(GENIEReWeight_SBN_v1_multisim_NormCCMEC, None)--
# 	Fractional uncertainty: 9.83%
# --Systematic(GENIEReWeight_SBN_v1_multisim_NormNCMEC, None)--
# 	Fractional uncertainty: 0.00%
# --Systematic(GENIEReWeight_SBN_v1_multisim_NCELVariationResponse, None)--
# 	Fractional uncertainty: 0.04%
# --Systematic(GENIEReWeight_SBN_v1_multisim_CCRESVariationResponse, None)--
# 	Fractional uncertainty: 5.02%
# --Systematic(GENIEReWeight_SBN_v1_multisim_NCRESVariationResponse, None)--
# 	Fractional uncertainty: 0.45%
# --Systematic(GENIEReWeight_SBN_v1_multisim_NonRESBGvpCC1pi, None)--
# 	Fractional uncertainty: 0.04%
# --Systematic(GENIEReWeight_SBN_v1_multisim_NonRESBGvpCC2pi, None)--
# 	Fractional uncertainty: 0.27%
# --Systematic(GENIEReWeight_SBN_v1_multisim_NonRESBGvpNC1pi, None)--
# 	Fractional uncertainty: 0.01%
# --Systematic(GENIEReWeight_SBN_v1_multisim_NonRESBGvpNC2pi, None)--
# 	Fractional uncertainty: 0.05%
# --Systematic(GENIEReWeight_SBN_v1_multisim_NonRESBGvnCC1pi, None)--
# 	Fractional uncertainty: 0.29%
# --Systematic(GENIEReWeight_SBN_v1_multisim_NonRESBGvnCC2pi, None)--
# 	Fractional uncertainty: 0.32%
# --Systematic(GENIEReWeight_SBN_v1_multisim_NonRESBGvnNC1pi, None)--
# 	Fractional uncertainty: 0.20%
# --Systematic(GENIEReWeight_SBN_v1_multisim_NonRESBGvnNC2pi, None)--
# 	Fractional uncertainty: 0.02%
# --Systematic(GENIEReWeight_SBN_v1_multisim_NonRESBGvbarpCC1pi, None)--
# 	Fractional uncertainty: 0.05%
# --Systematic(GENIEReWeight_SBN_v1_multisim_NonRESBGvbarpCC2pi, None)--
# 	Fractional uncertainty: 0.06%
# --Systematic(GENIEReWeight_SBN_v1_multisim_NonRESBGvbarpNC1pi, None)--
# 	Fractional uncertainty: 0.01%
# --Systematic(GENIEReWeight_SBN_v1_multisim_NonRESBGvbarpNC2pi, None)--
# 	Fractional uncertainty: 0.01%
# --Systematic(GENIEReWeight_SBN_v1_multisim_NonRESBGvbarnCC1pi, None)--
# 	Fractional uncertainty: 0.02%
# --Systematic(GENIEReWeight_SBN_v1_multisim_NonRESBGvbarnCC2pi, None)--
# 	Fractional uncertainty: 0.07%
# --Systematic(GENIEReWeight_SBN_v1_multisim_NonRESBGvbarnNC1pi, None)--
# 	Fractional uncertainty: 0.01%
# --Systematic(GENIEReWeight_SBN_v1_multisim_NonRESBGvbarnNC2pi, None)--
# 	Fractional uncertainty: 0.01%
# --Systematic(GENIEReWeight_SBN_v1_multisim_RDecBR1gamma, None)--
# 	Fractional uncertainty: 0.01%
# --Systematic(GENIEReWeight_SBN_v1_multisim_RDecBR1eta, None)--
# 	Fractional uncertainty: 0.40%
# --Systematic(GENIEReWeight_SBN_v1_multisim_COHVariationResponse, None)--
# 	Fractional uncertainty: 0.08%
# --Systematic(GENIEReWeight_SBN_v1_multisim_DISBYVariationResponse, None)--
# 	Fractional uncertainty: 0.03%
# --Systematic(GENIEReWeight_SBN_v1_multisim_FSI_pi_VariationResponse, None)--
# 	Fractional uncertainty: 4.03%
# --Systematic(GENIEReWeight_SBN_v1_multisim_FSI_N_VariationResponse, None)--
# 	Fractional uncertainty: 2.08%
# --Systematic(MINERvAE2p2h_SBN_v1_E2p2h_A_nu, None)--
# 	Fractional uncertainty: 10.82%
# --Systematic(MINERvAE2p2h_SBN_v1_E2p2h_B_nu, None)--
# 	Fractional uncertainty: 13.61%
# --Systematic(MINERvAE2p2h_SBN_v1_E2p2h_A_nubar, None)--
# 	Fractional uncertainty: 1.03%
# --Systematic(MINERvAE2p2h_SBN_v1_E2p2h_B_nubar, None)--
# 	Fractional uncertainty: 1.54%
# --Systematic(MINERvAg0q3Weighting_SBN_v1_Mnv202hGaussEnhancement, None)--
# 	Fractional uncertainty: 10.78%
# --Systematic(MiscInteractionSysts_SBN_v1_C12ToAr40_2p2hScaling_nu, None)--
# 	Fractional uncertainty: 7.69%
# --Systematic(MiscInteractionSysts_SBN_v1_C12ToAr40_2p2hScaling_nubar, None)--
# 	Fractional uncertainty: 0.83%
# --Systematic(MiscInteractionSysts_SBN_v1_nuenuebar_xsec_ratio, None)--
# 	Fractional uncertainty: 0.00%
# --Systematic(MiscInteractionSysts_SBN_v1_nuenumu_xsec_ratio, None)--
# 	Fractional uncertainty: 0.01%
# --Systematic(MiscInteractionSysts_SBN_v1_SPPLowQ2Suppression, None)--
# 	Fractional uncertainty: 2.01%
# --Systematic(NOvAStyleNonResPionNorm_SBN_v1_NR_nu_n_CC_2Pi, None)--
# 	Fractional uncertainty: 0.65%
# --Systematic(NOvAStyleNonResPionNorm_SBN_v1_NR_nu_n_CC_3Pi, None)--
# 	Fractional uncertainty: 0.07%
# --Systematic(NOvAStyleNonResPionNorm_SBN_v1_NR_nu_p_CC_2Pi, None)--
# 	Fractional uncertainty: 0.54%
# --Systematic(NOvAStyleNonResPionNorm_SBN_v1_NR_nu_p_CC_3Pi, None)--
# 	Fractional uncertainty: 0.10%
# --Systematic(NOvAStyleNonResPionNorm_SBN_v1_NR_nu_np_CC_1Pi, None)--
# 	Fractional uncertainty: 0.42%
# --Systematic(NOvAStyleNonResPionNorm_SBN_v1_NR_nu_n_NC_1Pi, None)--
# 	Fractional uncertainty: 0.37%
# --Systematic(NOvAStyleNonResPionNorm_SBN_v1_NR_nu_n_NC_2Pi, None)--
# 	Fractional uncertainty: 0.05%
# --Systematic(NOvAStyleNonResPionNorm_SBN_v1_NR_nu_n_NC_3Pi, None)--
# 	Fractional uncertainty: 0.02%
# --Systematic(NOvAStyleNonResPionNorm_SBN_v1_NR_nu_p_NC_1Pi, None)--
# 	Fractional uncertainty: 0.04%
# --Systematic(NOvAStyleNonResPionNorm_SBN_v1_NR_nu_p_NC_2Pi, None)--
# 	Fractional uncertainty: 0.11%
# --Systematic(NOvAStyleNonResPionNorm_SBN_v1_NR_nu_p_NC_3Pi, None)--
# 	Fractional uncertainty: 0.04%
# --Systematic(NOvAStyleNonResPionNorm_SBN_v1_NR_nubar_n_CC_1Pi, None)--
# 	Fractional uncertainty: 0.05%
# --Systematic(NOvAStyleNonResPionNorm_SBN_v1_NR_nubar_n_CC_2Pi, None)--
# 	Fractional uncertainty: 0.14%
# --Systematic(NOvAStyleNonResPionNorm_SBN_v1_NR_nubar_n_CC_3Pi, None)--
# 	Fractional uncertainty: 0.04%
# --Systematic(NOvAStyleNonResPionNorm_SBN_v1_NR_nubar_p_CC_1Pi, None)--
# 	Fractional uncertainty: 0.09%
# --Systematic(NOvAStyleNonResPionNorm_SBN_v1_NR_nubar_p_CC_2Pi, None)--
# 	Fractional uncertainty: 0.11%
# --Systematic(NOvAStyleNonResPionNorm_SBN_v1_NR_nubar_p_CC_3Pi, None)--
# 	Fractional uncertainty: 0.00%
# --Systematic(NOvAStyleNonResPionNorm_SBN_v1_NR_nubar_n_NC_1Pi, None)--
# 	Fractional uncertainty: 0.03%
# --Systematic(NOvAStyleNonResPionNorm_SBN_v1_NR_nubar_n_NC_2Pi, None)--
# 	Fractional uncertainty: 0.02%
# --Systematic(NOvAStyleNonResPionNorm_SBN_v1_NR_nubar_n_NC_3Pi, None)--
# 	Fractional uncertainty: 0.01%
# --Systematic(NOvAStyleNonResPionNorm_SBN_v1_NR_nubar_p_NC_1Pi, None)--
# 	Fractional uncertainty: 0.03%
# --Systematic(NOvAStyleNonResPionNorm_SBN_v1_NR_nubar_p_NC_2Pi, None)--
# 	Fractional uncertainty: 0.02%
# --Systematic(NOvAStyleNonResPionNorm_SBN_v1_NR_nubar_p_NC_3Pi, None)--
# 	Fractional uncertainty: 0.01%
# --Systematic(expskin_Flux, None)--
# 	Fractional uncertainty: 1.42%
# --Systematic(horncurrent_Flux, None)--
# 	Fractional uncertainty: 0.27%
# --Systematic(kminus_Flux, None)--
# 	Fractional uncertainty: 1.72%
# --Systematic(kplus_Flux, None)--
# 	Fractional uncertainty: 1.61%
# --Systematic(kzero_Flux, None)--
# 	Fractional uncertainty: 0.63%
# --Systematic(nucleoninexsec_Flux, None)--
# 	Fractional uncertainty: 0.95%
# --Systematic(nucleonqexsec_Flux, None)--
# 	Fractional uncertainty: 3.07%
# --Systematic(nucleontotxsec_Flux, None)--
# 	Fractional uncertainty: 0.77%
# --Systematic(piminus_Flux, None)--
# 	Fractional uncertainty: 0.41%
# --Systematic(pioninexsec_Flux, None)--
# 	Fractional uncertainty: 0.48%
# --Systematic(pionqexsec_Flux, None)--
# 	Fractional uncertainty: 0.31%
# --Systematic(piontotxsec_Flux, None)--
# 	Fractional uncertainty: 0.44%
# --Systematic(piplus_Flux, None)--
# 	Fractional uncertainty: 3.28%
# --Systematic(GENIEReWeight_SBN_v1_multisigma_ZExpA1CCQE, None)--
# 	Fractional uncertainty: 23.36%
# --Systematic(GENIEReWeight_SBN_v1_multisigma_ZExpA1CCQE_sigma, None)--
# 	Fractional uncertainty: 238.04%
# --Systematic(GENIEReWeight_SBN_v1_multisigma_ZExpA2CCQE, None)--
# 	Fractional uncertainty: 3.88%
# --Systematic(GENIEReWeight_SBN_v1_multisigma_ZExpA2CCQE_sigma, None)--
# 	Fractional uncertainty: 238.04%
# --Systematic(GENIEReWeight_SBN_v1_multisigma_ZExpA3CCQE, None)--
# 	Fractional uncertainty: 6.31%
# --Systematic(GENIEReWeight_SBN_v1_multisigma_ZExpA3CCQE_sigma, None)--
# 	Fractional uncertainty: 238.04%
# --Systematic(GENIEReWeight_SBN_v1_multisigma_ZExpA4CCQE, None)--
# 	Fractional uncertainty: 2.21%
# --Systematic(GENIEReWeight_SBN_v1_multisigma_ZExpA4CCQE_sigma, None)--
# 	Fractional uncertainty: 238.04%
# --Systematic(GENIEReWeight_SBN_v1_multisigma_VecFFCCQEshape, None)--
# 	Fractional uncertainty: 0.01%
# --Systematic(GENIEReWeight_SBN_v1_multisigma_VecFFCCQEshape_sigma, None)--
# 	Fractional uncertainty: 238.04%
# --Systematic(GENIEReWeight_SBN_v1_multisigma_RPA_CCQE, None)--
# 	Fractional uncertainty: 2.90%
# --Systematic(GENIEReWeight_SBN_v1_multisigma_RPA_CCQE_sigma, None)--
# 	Fractional uncertainty: 238.04%
# --Systematic(GENIEReWeight_SBN_v1_multisigma_CoulombCCQE, None)--
# 	Fractional uncertainty: 0.63%
# --Systematic(GENIEReWeight_SBN_v1_multisigma_CoulombCCQE_sigma, None)--
# 	Fractional uncertainty: 238.04%
# --Systematic(GENIEReWeight_SBN_v1_multisigma_NormCCMEC, None)--
# 	Fractional uncertainty: 19.29%
# --Systematic(GENIEReWeight_SBN_v1_multisigma_NormCCMEC_sigma, None)--
# 	Fractional uncertainty: 238.04%
# --Systematic(GENIEReWeight_SBN_v1_multisigma_NormNCMEC, None)--
# 	Fractional uncertainty: 0.00%
# --Systematic(GENIEReWeight_SBN_v1_multisigma_NormNCMEC_sigma, None)--
# 	Fractional uncertainty: 238.04%
# --Systematic(GENIEReWeight_SBN_v1_multisigma_DecayAngMEC, None)--
# 	Fractional uncertainty: 0.78%
# --Systematic(GENIEReWeight_SBN_v1_multisigma_DecayAngMEC_sigma, None)--
# 	Fractional uncertainty: 238.04%
# --Systematic(GENIEReWeight_SBN_v1_multisigma_MaNCEL, None)--
# 	Fractional uncertainty: 0.12%
# --Systematic(GENIEReWeight_SBN_v1_multisigma_MaNCEL_sigma, None)--
# 	Fractional uncertainty: 238.04%
# --Systematic(GENIEReWeight_SBN_v1_multisigma_EtaNCEL, None)--
# 	Fractional uncertainty: 0.00%
# --Systematic(GENIEReWeight_SBN_v1_multisigma_EtaNCEL_sigma, None)--
# 	Fractional uncertainty: 238.04%
# --Systematic(GENIEReWeight_SBN_v1_multisigma_MaCCRES, None)--
# 	Fractional uncertainty: 7.73%
# --Systematic(GENIEReWeight_SBN_v1_multisigma_MaCCRES_sigma, None)--
# 	Fractional uncertainty: 238.04%
# --Systematic(GENIEReWeight_SBN_v1_multisigma_MvCCRES, None)--
# 	Fractional uncertainty: 6.96%
# --Systematic(GENIEReWeight_SBN_v1_multisigma_MvCCRES_sigma, None)--
# 	Fractional uncertainty: 238.04%
# --Systematic(GENIEReWeight_SBN_v1_multisigma_MaNCRES, None)--
# 	Fractional uncertainty: 0.83%
# --Systematic(GENIEReWeight_SBN_v1_multisigma_MaNCRES_sigma, None)--
# 	Fractional uncertainty: 238.04%
# --Systematic(GENIEReWeight_SBN_v1_multisigma_MvNCRES, None)--
# 	Fractional uncertainty: 0.31%
# --Systematic(GENIEReWeight_SBN_v1_multisigma_MvNCRES_sigma, None)--
# 	Fractional uncertainty: 238.04%
# --Systematic(GENIEReWeight_SBN_v1_multisigma_NonRESBGvpCC1pi, None)--
# 	Fractional uncertainty: 0.10%
# --Systematic(GENIEReWeight_SBN_v1_multisigma_NonRESBGvpCC1pi_sigma, None)--
# 	Fractional uncertainty: 238.04%
# --Systematic(GENIEReWeight_SBN_v1_multisigma_NonRESBGvpCC2pi, None)--
# 	Fractional uncertainty: 0.52%
# --Systematic(GENIEReWeight_SBN_v1_multisigma_NonRESBGvpCC2pi_sigma, None)--
# 	Fractional uncertainty: 238.04%
# --Systematic(GENIEReWeight_SBN_v1_multisigma_NonRESBGvpNC1pi, None)--
# 	Fractional uncertainty: 0.02%
# --Systematic(GENIEReWeight_SBN_v1_multisigma_NonRESBGvpNC1pi_sigma, None)--
# 	Fractional uncertainty: 238.04%
# --Systematic(GENIEReWeight_SBN_v1_multisigma_NonRESBGvpNC2pi, None)--
# 	Fractional uncertainty: 0.10%
# --Systematic(GENIEReWeight_SBN_v1_multisigma_NonRESBGvpNC2pi_sigma, None)--
# 	Fractional uncertainty: 238.04%
# --Systematic(GENIEReWeight_SBN_v1_multisigma_NonRESBGvnCC1pi, None)--
# 	Fractional uncertainty: 0.55%
# --Systematic(GENIEReWeight_SBN_v1_multisigma_NonRESBGvnCC1pi_sigma, None)--
# 	Fractional uncertainty: 238.04%
# --Systematic(GENIEReWeight_SBN_v1_multisigma_NonRESBGvnCC2pi, None)--
# 	Fractional uncertainty: 0.64%
# --Systematic(GENIEReWeight_SBN_v1_multisigma_NonRESBGvnCC2pi_sigma, None)--
# 	Fractional uncertainty: 238.04%
# --Systematic(GENIEReWeight_SBN_v1_multisigma_NonRESBGvnNC1pi, None)--
# 	Fractional uncertainty: 0.33%
# --Systematic(GENIEReWeight_SBN_v1_multisigma_NonRESBGvnNC1pi_sigma, None)--
# 	Fractional uncertainty: 238.04%
# --Systematic(GENIEReWeight_SBN_v1_multisigma_NonRESBGvnNC2pi, None)--
# 	Fractional uncertainty: 0.05%
# --Systematic(GENIEReWeight_SBN_v1_multisigma_NonRESBGvnNC2pi_sigma, None)--
# 	Fractional uncertainty: 238.04%
# --Systematic(GENIEReWeight_SBN_v1_multisigma_NonRESBGvbarpCC1pi, None)--
# 	Fractional uncertainty: 0.09%
# --Systematic(GENIEReWeight_SBN_v1_multisigma_NonRESBGvbarpCC1pi_sigma, None)--
# 	Fractional uncertainty: 238.04%
# --Systematic(GENIEReWeight_SBN_v1_multisigma_NonRESBGvbarpCC2pi, None)--
# 	Fractional uncertainty: 0.11%
# --Systematic(GENIEReWeight_SBN_v1_multisigma_NonRESBGvbarpCC2pi_sigma, None)--
# 	Fractional uncertainty: 238.04%
# --Systematic(GENIEReWeight_SBN_v1_multisigma_NonRESBGvbarpNC1pi, None)--
# 	Fractional uncertainty: 0.02%
# --Systematic(GENIEReWeight_SBN_v1_multisigma_NonRESBGvbarpNC1pi_sigma, None)--
# 	Fractional uncertainty: 238.04%
# --Systematic(GENIEReWeight_SBN_v1_multisigma_NonRESBGvbarpNC2pi, None)--
# 	Fractional uncertainty: 0.01%
# --Systematic(GENIEReWeight_SBN_v1_multisigma_NonRESBGvbarpNC2pi_sigma, None)--
# 	Fractional uncertainty: 238.04%
# --Systematic(GENIEReWeight_SBN_v1_multisigma_NonRESBGvbarnCC1pi, None)--
# 	Fractional uncertainty: 0.04%
# --Systematic(GENIEReWeight_SBN_v1_multisigma_NonRESBGvbarnCC1pi_sigma, None)--
# 	Fractional uncertainty: 238.04%
# --Systematic(GENIEReWeight_SBN_v1_multisigma_NonRESBGvbarnCC2pi, None)--
# 	Fractional uncertainty: 0.14%
# --Systematic(GENIEReWeight_SBN_v1_multisigma_NonRESBGvbarnCC2pi_sigma, None)--
# 	Fractional uncertainty: 238.04%
# --Systematic(GENIEReWeight_SBN_v1_multisigma_NonRESBGvbarnNC1pi, None)--
# 	Fractional uncertainty: 0.02%
# --Systematic(GENIEReWeight_SBN_v1_multisigma_NonRESBGvbarnNC1pi_sigma, None)--
# 	Fractional uncertainty: 238.04%
# --Systematic(GENIEReWeight_SBN_v1_multisigma_NonRESBGvbarnNC2pi, None)--
# 	Fractional uncertainty: 0.02%
# --Systematic(GENIEReWeight_SBN_v1_multisigma_NonRESBGvbarnNC2pi_sigma, None)--
# 	Fractional uncertainty: 238.04%
# --Systematic(GENIEReWeight_SBN_v1_multisigma_RDecBR1gamma, None)--
# 	Fractional uncertainty: 0.02%
# --Systematic(GENIEReWeight_SBN_v1_multisigma_RDecBR1gamma_sigma, None)--
# 	Fractional uncertainty: 238.04%
# --Systematic(GENIEReWeight_SBN_v1_multisigma_RDecBR1eta, None)--
# 	Fractional uncertainty: 0.87%
# --Systematic(GENIEReWeight_SBN_v1_multisigma_RDecBR1eta_sigma, None)--
# 	Fractional uncertainty: 238.04%
# --Systematic(GENIEReWeight_SBN_v1_multisigma_Theta_Delta2Npi, None)--
# 	Fractional uncertainty: 0.44%
# --Systematic(GENIEReWeight_SBN_v1_multisigma_Theta_Delta2Npi_sigma, None)--
# 	Fractional uncertainty: 238.04%
# --Systematic(GENIEReWeight_SBN_v1_multisigma_ThetaDelta2NRad, None)--
# 	Fractional uncertainty: 0.01%
# --Systematic(GENIEReWeight_SBN_v1_multisigma_ThetaDelta2NRad_sigma, None)--
# 	Fractional uncertainty: 238.04%
# --Systematic(GENIEReWeight_SBN_v1_multisigma_NormCCCOH, None)--
# 	Fractional uncertainty: 0.15%
# --Systematic(GENIEReWeight_SBN_v1_multisigma_NormCCCOH_sigma, None)--
# 	Fractional uncertainty: 238.04%
# --Systematic(GENIEReWeight_SBN_v1_multisigma_NormNCCOH, None)--
# 	Fractional uncertainty: 0.00%
# --Systematic(GENIEReWeight_SBN_v1_multisigma_NormNCCOH_sigma, None)--
# 	Fractional uncertainty: 238.04%
# --Systematic(GENIEReWeight_SBN_v1_multisigma_AhtBY, None)--
# 	Fractional uncertainty: 0.03%
# --Systematic(GENIEReWeight_SBN_v1_multisigma_AhtBY_sigma, None)--
# 	Fractional uncertainty: 238.04%
# --Systematic(GENIEReWeight_SBN_v1_multisigma_BhtBY, None)--
# 	Fractional uncertainty: 0.05%
# --Systematic(GENIEReWeight_SBN_v1_multisigma_BhtBY_sigma, None)--
# 	Fractional uncertainty: 238.04%
# --Systematic(GENIEReWeight_SBN_v1_multisigma_CV1uBY, None)--
# 	Fractional uncertainty: 0.04%
# --Systematic(GENIEReWeight_SBN_v1_multisigma_CV1uBY_sigma, None)--
# 	Fractional uncertainty: 238.04%
# --Systematic(GENIEReWeight_SBN_v1_multisigma_CV2uBY, None)--
# 	Fractional uncertainty: 0.03%
# --Systematic(GENIEReWeight_SBN_v1_multisigma_CV2uBY_sigma, None)--
# 	Fractional uncertainty: 238.04%
# --Systematic(GENIEReWeight_SBN_v1_multisigma_MFP_pi, None)--
# 	Fractional uncertainty: 1.67%
# --Systematic(GENIEReWeight_SBN_v1_multisigma_MFP_pi_sigma, None)--
# 	Fractional uncertainty: 238.04%
# --Systematic(GENIEReWeight_SBN_v1_multisigma_FrCEx_pi, None)--
# 	Fractional uncertainty: 4.39%
# --Systematic(GENIEReWeight_SBN_v1_multisigma_FrCEx_pi_sigma, None)--
# 	Fractional uncertainty: 238.04%
# --Systematic(GENIEReWeight_SBN_v1_multisigma_FrInel_pi, None)--
# 	Fractional uncertainty: 3.02%
# --Systematic(GENIEReWeight_SBN_v1_multisigma_FrInel_pi_sigma, None)--
# 	Fractional uncertainty: 238.04%
# --Systematic(GENIEReWeight_SBN_v1_multisigma_FrAbs_pi, None)--
# 	Fractional uncertainty: 8.72%
# --Systematic(GENIEReWeight_SBN_v1_multisigma_FrAbs_pi_sigma, None)--
# 	Fractional uncertainty: 238.04%
# --Systematic(GENIEReWeight_SBN_v1_multisigma_FrPiProd_pi, None)--
# 	Fractional uncertainty: 1.38%
# --Systematic(GENIEReWeight_SBN_v1_multisigma_FrPiProd_pi_sigma, None)--
# 	Fractional uncertainty: 238.04%
# --Systematic(GENIEReWeight_SBN_v1_multisigma_MFP_N, None)--
# 	Fractional uncertainty: 3.88%
# --Systematic(GENIEReWeight_SBN_v1_multisigma_MFP_N_sigma, None)--
# 	Fractional uncertainty: 238.04%
# --Systematic(GENIEReWeight_SBN_v1_multisigma_FrCEx_N, None)--
# 	Fractional uncertainty: 3.65%
# --Systematic(GENIEReWeight_SBN_v1_multisigma_FrCEx_N_sigma, None)--
# 	Fractional uncertainty: 238.04%
# --Systematic(GENIEReWeight_SBN_v1_multisigma_FrInel_N, None)--
# 	Fractional uncertainty: 1.08%
# --Systematic(GENIEReWeight_SBN_v1_multisigma_FrInel_N_sigma, None)--
# 	Fractional uncertainty: 238.04%
# --Systematic(GENIEReWeight_SBN_v1_multisigma_FrAbs_N, None)--
# 	Fractional uncertainty: 2.75%
# --Systematic(GENIEReWeight_SBN_v1_multisigma_FrAbs_N_sigma, None)--
# 	Fractional uncertainty: 238.04%
# --Systematic(GENIEReWeight_SBN_v1_multisigma_FrPiProd_N, None)--
# 	Fractional uncertainty: 0.83%
# --Systematic(GENIEReWeight_SBN_v1_multisigma_FrPiProd_N_sigma, None)--
# 	Fractional uncertainty: 238.04%
# --Systematic(hysyst_beam_horn_2kA_v, None)--
# 	Fractional uncertainty: 0.10%
# --Systematic(hysyst_beam_horn1_x_3mm_v, None)--
# 	Fractional uncertainty: 0.04%
# --Systematic(hysyst_beam_horn1_y_3mm_v, None)--
# 	Fractional uncertainty: 0.27%
# --Systematic(hysyst_beam_spot_1_3mm_v, None)--
# 	Fractional uncertainty: 1.15%
# --Systematic(hysyst_beam_spot_1_7mm_v, None)--
# 	Fractional uncertainty: 1.92%
# --Systematic(hysyst_beam_horn2_x_3mm_v, None)--
# 	Fractional uncertainty: 0.08%
# --Systematic(hysyst_beam_horn2_y_3mm_v, None)--
# 	Fractional uncertainty: 0.08%
# --Systematic(hysyst_beam_horns_0mm_water_v, None)--
# 	Fractional uncertainty: 0.14%
# --Systematic(hysyst_beam_horns_2mm_water_v, None)--
# 	Fractional uncertainty: 0.24%
# --Systematic(hysyst_beam_Beam_shift_x_1mm_v, None)--
# 	Fractional uncertainty: 1.85%
# --Systematic(hysyst_beam_Beam_shift_y_1mm_v, None)--
# 	Fractional uncertainty: 1.95%
# --Systematic(hysyst_beam_Target_z_7mm_v, None)--
# 	Fractional uncertainty: 0.18%
# --Systematic(hysyst_hpc_0_v, None)--
# 	Fractional uncertainty: 4.62%
# --Systematic(hysyst_hpc_1_v, None)--
# 	Fractional uncertainty: 2.71%
# --Systematic(hysyst_hpc_2_v, None)--
# 	Fractional uncertainty: 1.72%
# --Systematic(hysyst_hpc_3_v, None)--
# 	Fractional uncertainty: 0.31%
# --Systematic(hysyst_hpc_4_v, None)--
# 	Fractional uncertainty: 4.01%
# --Systematic(hysyst_hpc_5_v, None)--
# 	Fractional uncertainty: 2.50%
# --Systematic(hysyst_hpc_6_v, None)--
# 	Fractional uncertainty: 0.36%
# --Systematic(hysyst_hpc_7_v, None)--
# 	Fractional uncertainty: 0.61%
# --Systematic(hysyst_hpc_8_v, None)--
# 	Fractional uncertainty: 1.18%
# --Systematic(hysyst_hpc_9_v, None)--
# 	Fractional uncertainty: 0.28%
# --Systematic(hysyst_hpc_10_v, None)--
# 	Fractional uncertainty: 0.44%
# --Systematic(hysyst_hpc_11_v, None)--
# 	Fractional uncertainty: 0.09%
# --Systematic(hysyst_hpc_12_v, None)--
# 	Fractional uncertainty: 0.02%
# --Systematic(hysyst_hpc_13_v, None)--
# 	Fractional uncertainty: 0.04%
# --Systematic(hysyst_hpc_14_v, None)--
# 	Fractional uncertainty: 0.02%
# --Systematic(hysyst_beam_horn_2kA_sigma, None)--
# 	Fractional uncertainty: 146.94%
# --Systematic(hysyst_beam_horn1_x_3mm_sigma, None)--
# 	Fractional uncertainty: 140.25%
# --Systematic(hysyst_beam_horn1_y_3mm_sigma, None)--
# 	Fractional uncertainty: 137.70%
# --Systematic(hysyst_beam_spot_1_3mm_sigma, None)--
# 	Fractional uncertainty: 144.16%
# --Systematic(hysyst_beam_spot_1_7mm_sigma, None)--
# 	Fractional uncertainty: 141.81%
# --Systematic(hysyst_beam_horn2_x_3mm_sigma, None)--
# 	Fractional uncertainty: 142.32%
# --Systematic(hysyst_beam_horn2_y_3mm_sigma, None)--
# 	Fractional uncertainty: 137.43%
# --Systematic(hysyst_beam_horns_0mm_water_sigma, None)--
# 	Fractional uncertainty: 143.14%
# --Systematic(hysyst_beam_horns_2mm_water_sigma, None)--
# 	Fractional uncertainty: 136.78%
# --Systematic(hysyst_beam_Beam_shift_x_1mm_sigma, None)--
# 	Fractional uncertainty: 140.63%
# --Systematic(hysyst_beam_Beam_shift_y_1mm_sigma, None)--
# 	Fractional uncertainty: 134.57%
# --Systematic(hysyst_beam_Target_z_7mm_sigma, None)--
# 	Fractional uncertainty: 141.44%
# --Systematic(hysyst_hpc_0_sigma, None)--
# 	Fractional uncertainty: 144.80%
# --Systematic(hysyst_hpc_1_sigma, None)--
# 	Fractional uncertainty: 143.46%
# --Systematic(hysyst_hpc_2_sigma, None)--
# 	Fractional uncertainty: 143.79%
# --Systematic(hysyst_hpc_3_sigma, None)--
# 	Fractional uncertainty: 144.53%
# --Systematic(hysyst_hpc_4_sigma, None)--
# 	Fractional uncertainty: 144.28%
# --Systematic(hysyst_hpc_5_sigma, None)--
# 	Fractional uncertainty: 141.06%
# --Systematic(hysyst_hpc_6_sigma, None)--
# 	Fractional uncertainty: 137.43%
# --Systematic(hysyst_hpc_7_sigma, None)--
# 	Fractional uncertainty: 141.00%
# --Systematic(hysyst_hpc_8_sigma, None)--
# 	Fractional uncertainty: 137.52%
# --Systematic(hysyst_hpc_9_sigma, None)--
# 	Fractional uncertainty: 139.19%
# --Systematic(hysyst_hpc_10_sigma, None)--
# 	Fractional uncertainty: 142.76%
# --Systematic(hysyst_hpc_11_sigma, None)--
# 	Fractional uncertainty: 136.95%
# --Systematic(hysyst_hpc_12_sigma, None)--
# 	Fractional uncertainty: 138.68%
# --Systematic(hysyst_hpc_13_sigma, None)--
# 	Fractional uncertainty: 142.38%
# --Systematic(hysyst_hpc_14_sigma, None)--
# 	Fractional uncertainty: 136.40%
# --Systematic(statistical, None)--
# 	Fractional uncertainty: 0.68%
# --Systematic(stats, Stat.)--
# 	Fractional uncertainty: 0.68%
# --Systematic(flux, Flux)--
# 	Fractional uncertainty: 8.29%
# --Systematic(xsec, Cross-section)--
# 	Fractional uncertainty: 15.69%
# --Systematic(MC_total, Flux & Interaction Uncertainty)--
# 	Fractional uncertainty: 17.76%
#
# ============================================================
# Processing systematics for sample: onbeam
# ============================================================
# Setting weight for mc to 1.51e-01
# Setting weight for onbeam to 1.00e+00
# /Users/rvizarreta/Library/CloudStorage/GoogleDrive-rvizarreta14@gmail.com/My Drive/🏛 PhD Repository/🚀 Research/🤖 Experiments&Projects/ICARUS/ICARUS_CC0pi_Selection/ICARUS-NuMI-CC0pi-Selection/spineplot/myAnalysis/../spectra1d.py:597: RuntimeWarning: invalid value encountered in divide
#   f"Fractional - Min: {(uncertainty / y_pred).min():.2%}, Max: {(uncertainty / y_pred).max():.2%}")
# Fractional - Min: nan%, Max: nan%
# Fractional - Min: nan%, Max: nan%
# Fractional - Min: nan%, Max: nan%

# %%
# Opening Angle
analysis = Analysis(ana_directory + '/opening_angle/opening_angle.toml', data_file)
analysis.run(close_figs=False)
# Out:
# ============================================================
# Processing systematics for sample: mc
# ============================================================
#
# ============================================================
# Processing systematics for sample: onbeam
# ============================================================
# Setting weight for mc to 1.51e-01
# Setting weight for onbeam to 1.00e+00
# Fractional - Min: 8.06%, Max: 8.62%
# Fractional - Min: 14.37%, Max: 23.58%
# Fractional - Min: 2.57%, Max: 5.77%

# %%
# Vertex X
analysis = Analysis(ana_directory + '/vertex_x/vertex_x.toml', data_file)
analysis.run(close_figs=False)
# Out:
# ============================================================
# Processing systematics for sample: mc
# ============================================================
#
# ============================================================
# Processing systematics for sample: onbeam
# ============================================================
# Setting weight for mc to 1.51e-01
# Setting weight for onbeam to 1.00e+00

# %%
# Vertex Y
analysis = Analysis(ana_directory + '/vertex_y/vertex_y.toml', data_file)
analysis.run(close_figs=False)
# Out:
# ============================================================
# Processing systematics for sample: mc
# ============================================================
#
# ============================================================
# Processing systematics for sample: onbeam
# ============================================================
# Setting weight for mc to 1.51e-01
# Setting weight for onbeam to 1.00e+00

# %%
# Vertex Z
analysis = Analysis(ana_directory + '/vertex_z/vertex_z.toml', data_file)
analysis.run(close_figs=False)
# Out:
# ============================================================
# Processing systematics for sample: mc
# ============================================================
#
# ============================================================
# Processing systematics for sample: onbeam
# ============================================================
# Setting weight for mc to 1.51e-01
# Setting weight for onbeam to 1.00e+00

# %%
data_file_no_systematics = '/Users/rvizarreta/Library/CloudStorage/GoogleDrive-rvizarreta14@gmail.com/My Drive/🏛 PhD Repository/🚀 Research/🤖 Experiments&Projects/ICARUS/ICARUS_CC0pi_Selection/data/1muNp0pi_Nge1_uncontained.root'
analysis = Analysis(ana_directory + '/efficiency.toml', data_file_no_systematics)
analysis.run(close_figs=False)
# Out:
# ============================================================
# Processing systematics for sample: signal
# ============================================================
# Setting weight for signal to 1.00e+00

# %%
# Delta p_T cross-section uncertainties plot
analysis = Analysis(ana_directory + '/dpT/dpT_xSecUncertainty.toml', data_file)
analysis.run(close_figs=False)
# Out:
# ---------------------------------------------------------------------------
# KeyInFileError                            Traceback (most recent call last)
# Cell In[5], line 2
#       1 # Delta p_T cross-section uncertainties plot
# ----> 2 analysis = Analysis(ana_directory + '/dpT/dpT_xSecUncertainty.toml', data_file)
#       3 analysis.run(close_figs=False)
#
# File ~/Library/CloudStorage/GoogleDrive-rvizarreta14@gmail.com/My Drive/🏛 PhD Repository/🚀 Research/🤖 Experiments&Projects/ICARUS/ICARUS_CC0pi_Selection/ICARUS-NuMI-CC0pi-Selection/spineplot/myAnalysis/../analysis.py:76, in Analysis.__init__(self, toml_path, rf_path)
#      74 if 'samples' not in self._config.keys():
#      75     raise ConfigException(f"No samples defined in the TOML file. Please check for a valid sample configuration block in the TOML file ('{toml_path}').")
# ---> 76 self._samples = {name: Sample(name, rf, self._config['analysis']['category_branch'], **self._config['samples'][name]) for name in self._config['samples']}
#      78 # Load the plot styles table
#      79 if 'style' not in self._config.keys():
#
# File ~/Library/CloudStorage/GoogleDrive-rvizarreta14@gmail.com/My Drive/🏛 PhD Repository/🚀 Research/🤖 Experiments&Projects/ICARUS/ICARUS_CC0pi_Selection/ICARUS-NuMI-CC0pi-Selection/spineplot/myAnalysis/../sample.py:127, in Sample.__init__(self, name, rf, category_branch, key, exposure_type, trees, systematics, override_exposure, precompute, presel, override_category, print_sys)
#     125 if systematics is not None:
#     126     for sys in systematics:
# --> 127         systs = [k for k in self._file_handle[sys].keys() if k not in ['Run', 'Subrun', 'Evt']]
#     128         self._systematics.update({syst: Systematic(syst, self._file_handle[sys][syst]) for syst in systs})
#     130 # Add statistical uncertainty. This can always be added to the
#     131 # sample, because it is not dependent on some external source
#     132 # of weights.
#
# File /opt/anaconda3/lib/python3.13/site-packages/uproot/reading.py:2122, in ReadOnlyDirectory.__getitem__(self, where)
#    2119     return step
#    2121 else:
# -> 2122     return self.key(where).get()
#
# File /opt/anaconda3/lib/python3.13/site-packages/uproot/reading.py:2064, in ReadOnlyDirectory.key(self, where)
#    2062     return last
#    2063 elif cycle is None:
# -> 2064     raise uproot.KeyInFileError(
#    2065         item, cycle="any", keys=self.keys(), file_path=self._file.file_path
#    2066     )
#    2067 else:
#    2068     raise uproot.KeyInFileError(
#    2069         item, cycle=cycle, keys=self.keys(), file_path=self._file.file_path
#    2070     )
#
# KeyInFileError: not found: 'multisimTree' (with any cycle number)
#
#     Available keys: 'signal_multisimTree;25', 'signal_multisimTree;24', 'sideband_multisimTree;7', 'sideband_multisimTree;6', 'Livetime;1', 'selected_multisimTree;22', 'selected_multisimTree;21', 'signal_multisigmaTree;25'...
#
# in file /Users/rvizarreta/Library/CloudStorage/GoogleDrive-rvizarreta14@gmail.com/My Drive/🏛 PhD Repository/🚀 Research/🤖 Experiments&Projects/ICARUS/ICARUS_CC0pi_Selection/data/icarus_numi_numu_mc_onbeam_offbeam_syst.root

# %%
# No charged pions - Truth
analysis = Analysis(ana_directory + '/pions_in_otherCC/pions_in_otherCC.toml', data_file)
analysis.run(close_figs=False)
# Out:
# ============================================================
# Processing systematics for sample: mc
# ============================================================
# --Systematic(statistical, None)--
# 	Fractional uncertainty: 0.68%
#
# ============================================================
# Processing systematics for sample: onbeam
# ============================================================
# Setting weight for mc to 1.51e-01
# Setting weight for onbeam to 1.00e+00

# %%
import uproot
f = uproot.open("/Users/rvizarreta/Library/CloudStorage/GoogleDrive-rvizarreta14@gmail.com/My Drive/🏛 PhD Repository/🚀 Research/🤖 Experiments&Projects/ICARUS/ICARUS_CC0pi_Selection/data/icarus_numi_numu_mc_onbeam_offbeam_syst.root")
t = f['events/full/selected']
for i, name in enumerate(t.keys()):
    print(i, name)
# Out:
# 0 reco_Q2
# 1 reco_W
# 2 reco_containment_cut
# 3 reco_cut_type
# 4 reco_dalphaT
# 5 reco_dalphaT_deg
# 6 reco_dpL
# 7 reco_dpL_lp
# 8 reco_dpT
# 9 reco_dpT_lp
# 10 reco_dphiT
# 11 reco_dphiT_deg
# 12 reco_electron_multiplicity
# 13 reco_fiducial
# 14 reco_flash_hypothesis
# 15 reco_flash_time
# 16 reco_flash_total_pe
# 17 reco_is_data
# 18 reco_is_nu
# 19 reco_leading_muon_azimuthal_angle
# 20 reco_leading_muon_containment
# 21 reco_leading_muon_csda_ke
# 22 reco_leading_muon_dpT
# 23 reco_leading_muon_end_x
# 24 reco_leading_muon_end_y
# 25 reco_leading_muon_end_z
# 26 reco_leading_muon_energy
# 27 reco_leading_muon_ke
# 28 reco_leading_muon_length
# 29 reco_leading_muon_mass
# 30 reco_leading_muon_mcs_ke
# 31 reco_leading_muon_momentum
# 32 reco_leading_muon_polar_angle
# 33 reco_leading_muon_polar_angle_cos
# 34 reco_leading_pion_containment
# 35 reco_leading_pion_energy
# 36 reco_leading_pion_ke
# 37 reco_leading_pion_length
# 38 reco_leading_pion_momentum
# 39 reco_leading_proton_containment
# 40 reco_leading_proton_csda_ke
# 41 reco_leading_proton_energy
# 42 reco_leading_proton_length
# 43 reco_leading_proton_mass
# 44 reco_leading_proton_mcs_ke
# 45 reco_leading_proton_momentum
# 46 reco_muon_multiplicity
# 47 reco_opening_angle_cos
# 48 reco_opening_angle_deg
# 49 reco_photon_multiplicity
# 50 reco_pion_multiplicity
# 51 reco_pn
# 52 reco_pn_lp
# 53 reco_proton_multiplicity
# 54 reco_vertex_x
# 55 reco_vertex_y
# 56 reco_vertex_z
# 57 reco_visible_energy
# 58 reco_visible_energy_calosub
# 59 true_Q2
# 60 true_W
# 61 true_baseline
# 62 true_category
# 63 true_cc
# 64 true_containment_cut
# 65 true_cut_type
# 66 true_dalphaT
# 67 true_dalphaT_deg
# 68 true_dpL
# 69 true_dpL_lp
# 70 true_dpT
# 71 true_dpT_lp
# 72 true_dphiT
# 73 true_dphiT_deg
# 74 true_interaction_mode
# 75 true_interaction_type
# 76 true_is_data
# 77 true_is_nu
# 78 true_leading_muon_azimuthal_angle
# 79 true_leading_muon_containment
# 80 true_leading_muon_csda_ke
# 81 true_leading_muon_dpT
# 82 true_leading_muon_end_x
# 83 true_leading_muon_end_y
# 84 true_leading_muon_end_z
# 85 true_leading_muon_energy
# 86 true_leading_muon_ke
# 87 true_leading_muon_length
# 88 true_leading_muon_mass
# 89 true_leading_muon_mcs_ke
# 90 true_leading_muon_momentum
# 91 true_leading_muon_polar_angle
# 92 true_leading_muon_polar_angle_cos
# 93 true_leading_pion_containment
# 94 true_leading_pion_energy
# 95 true_leading_pion_ke
# 96 true_leading_pion_length
# 97 true_leading_pion_momentum
# 98 true_leading_proton_containment
# 99 true_leading_proton_csda_ke
# 100 true_leading_proton_energy
# 101 true_leading_proton_length
# 102 true_leading_proton_mass
# 103 true_leading_proton_mcs_ke
# 104 true_leading_proton_momentum
# 105 true_neutrino_energy
# 106 true_neutrino_id
# 107 true_no_charged_pions
# 108 true_opening_angle_cos
# 109 true_opening_angle_deg
# 110 true_parent_pdg
# 111 true_pdg
# 112 true_pn
# 113 true_pn_lp
# 114 true_vertex_x
# 115 true_vertex_y
# 116 true_vertex_z
# 117 true_visible_energy
# 118 true_visible_energy_calosub
# 119 Run
# 120 Subrun
# 121 Evt
# 122 ppfx_cv_weight
# 123 ppfx_cv_weight
